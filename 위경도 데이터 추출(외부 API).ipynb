# %%
import pandas as pd
import requests
import time

# 🔑 카카오 REST API 키 입력
REST_API_KEY = "YOUR_REST_API_KEY"

def geocode(address):
    url = "https://dapi.kakao.com/v2/local/search/address.json"
    headers = {"Authorization": f"KakaoAK {"개인 API여서 비공개하겠음"}"}
    params = {"query": address}

    res = requests.get(url, headers=headers, params=params).json()

    if res.get('documents'):
        doc = res['documents'][0]
        address_info = doc.get('road_address') or doc.get('address')
        if address_info:
            x = address_info['x']  # 경도
            y = address_info['y']  # 위도
            return float(y), float(x)
    return None, None

df = pd.read_excel(r"C:\Users\KimGW\Desktop\중복 주소 제거.xlsx")


address_col = "주소" 

# 위경도 컬럼 추가
df["lat"] = None
df["lng"] = None


for i, addr in enumerate(df[address_col]):
    if pd.isna(addr):
        continue
    print(f"{i+1}/{len(df)} → {addr}")
    
    lat, lng = geocode(addr)
    df.at[i, "lat"] = lat
    df.at[i, "lng"] = lng

    time.sleep(0.2)


df.to_excel("output_with_latlng4.xlsx", index=False)
# Out:
# 1/8597 → 서울특별시 강서구 화곡동 1159
# 2/8597 → 서울특별시 서대문구 대현동 144
# 3/8597 → 서울특별시 동작구 사당동 169-32
# 4/8597 → 서울특별시 은평구 역촌동 43-4
# 5/8597 → 서울특별시 도봉구 방학동 734
# 6/8597 → 서울특별시 영등포구 대림동 762-1
# 7/8597 → 서울특별시 관악구 봉천동 1698-1
# 8/8597 → 서울특별시 구로구 구로동 107-4
# 9/8597 → 서울특별시 금천구 시흥동 1013
# 10/8597 → 서울특별시 서초구 방배동 763-12
# 11/8597 → 서울특별시 종로구 숭인동 181-121
# 12/8597 → 서울특별시 노원구 상계동 730-2
# 13/8597 → 서울특별시 영등포구 신길동 4942
# 14/8597 → 서울특별시 서초구 신원동 619
# 15/8597 → 서울특별시 송파구 잠실동 101-1
# 16/8597 → 서울특별시 도봉구 방학동 508
# 17/8597 → 서울특별시 노원구 상계동 624
# 18/8597 → 서울특별시 중랑구 신내동 795
# 19/8597 → 서울특별시 성북구 돈암동 524
# 20/8597 → 서울특별시 송파구 신천동 7
# 21/8597 → 서울특별시 강동구 길동 415-16
# 22/8597 → 서울특별시 성북구 성북동1가 35-22
# 23/8597 → 서울특별시 은평구 대조동 4-6
# 24/8597 → 서울특별시 마포구 창전동 443
# 25/8597 → 서울특별시 강남구 역삼동 709-5
# 26/8597 → 서울특별시 마포구 합정동 468
# 27/8597 → 서울특별시 도봉구 창동 38
# 28/8597 → 서울특별시 용산구 문배동 24-4
# 29/8597 → 서울특별시 은평구 신사동 155-1
# 30/8597 → 서울특별시 구로구 구로동 771-2
# 31/8597 → 서울특별시 강동구 천호동 22-9
# 32/8597 → 서울특별시 동대문구 장안동 384-1
# 33/8597 → 서울특별시 서초구 방배동 998
# 34/8597 → 서울특별시 강남구 수서동 559
# 35/8597 → 서울특별시 강동구 천호동 44
# 36/8597 → 서울특별시 양천구 목동 643-7
# 37/8597 → 서울특별시 은평구 불광동 645
# 38/8597 → 서울특별시 성북구 종암동 80
# 39/8597 → 서울특별시 도봉구 방학동 444-31
# 8591/8597 → 서울특별시 강서구 등촌동 637-32
# 8592/8597 → 서울특별시 강서구 염창동 283-15
# 8593/8597 → 서울특별시 동작구 대방동 403-16
# 8594/8597 → 서울특별시 강서구 화곡동 888-1
# 8595/8597 → 서울특별시 은평구 대조동 5-11
# 8596/8597 → 서울특별시 서초구 양재동 8-37
# 8597/8597 → 서울특별시 강동구 길동 480
# 파일 저장 완료: output_with_latlng.xlsx

# %%
import pandas as pd
import requests
import time

# 🔑 카카오 REST API 키 입력
REST_API_KEY = "개인 API여서 비공개하겠음"

def geocode(address, retries=3, timeout=5):
    """
    주소 → 위경도 변환
    retries: 실패 시 재시도 횟수
    timeout: 요청 제한 시간
    """
    url = "https://dapi.kakao.com/v2/local/search/address.json"
    headers = {"Authorization": f"KakaoAK {REST_API_KEY}"}
    params = {"query": address}

    for attempt in range(1, retries + 1):
        try:
            res = requests.get(url, headers=headers, params=params, timeout=timeout)
            res.raise_for_status()
            data = res.json()

            if data.get('documents'):
                doc = data['documents'][0]
                address_info = doc.get('road_address') or doc.get('address')
                if address_info:
                    x = address_info['x']  # 경도
                    y = address_info['y']  # 위도
                    return float(y), float(x)
            return None, None
        except requests.exceptions.RequestException as e:
            print(f"시도 {attempt} 실패: {address}, 오류: {e}")
            time.sleep(1)  # 재시도 전 잠시 대기
    return None, None  # 재시도 모두 실패 시

# 📌 엑셀 파일 로드
df = pd.read_excel(r"C:\Users\KimGW\Desktop\중복 주소 제거.xlsx")

# 📌 주소 컬럼 이름 확인
address_col = "주소"

# 위경도 컬럼 없으면 추가
if "lat" not in df.columns:
    df["lat"] = None
if "lng" not in df.columns:
    df["lng"] = None

# 📌 중단된 곳부터 이어서 처리
for i, addr in enumerate(df[address_col]):
    if pd.isna(addr):
        continue

    # 이미 위경도가 있다면 건너뛰기
    if pd.notna(df.at[i, "lat"]) and pd.notna(df.at[i, "lng"]):
        print(f"{i+1}/{len(df)} → 이미 처리됨, 건너뜀")
        continue

    print(f"{i+1}/{len(df)} → {addr}")
    lat, lng = geocode(addr)
    df.at[i, "lat"] = lat
    df.at[i, "lng"] = lng

    time.sleep(0.2)  # API 호출 제한 방지

# 📌 결과 저장
df.to_excel("output_with_latlng2344.xlsx", index=False)
print("파일 저장 완료: output_with_latlng.xlsx")

# %%
import pandas as pd
import requests
import time

# 🔑 카카오 REST API 키 입력
REST_API_KEY = "YOUR_REST_API_KEY"

def geocode(address):
    url = "https://dapi.kakao.com/v2/local/search/address.json"
    headers = {"Authorization": f"KakaoAK {"개인 API여서 비공개하겠음"}"}
    params = {"query": address}

    res = requests.get(url, headers=headers, params=params).json()

    if res.get('documents'):
        doc = res['documents'][0]
        # 일부 주소는 'road_address', 일부는 'address' 만 있음 → 안전하게 처리
        address_info = doc.get('road_address') or doc.get('address')
        if address_info:
            x = address_info['x']  # 경도
            y = address_info['y']  # 위도
            return float(y), float(x)
    return None, None


# 📌 엑셀 파일 로드
df = pd.read_excel(r"C:\Users\KimGW\Desktop\통합 문서1.xlsx")

# 📌 주소 컬럼 이름을 파일에 맞게 수정
address_col = "주소"   # 예: "주소", "address", "addr" 등

# 위경도 컬럼 추가
df["lat"] = None
df["lng"] = None

# 📌 각 주소에 대해 위경도 얻기
for i, addr in enumerate(df[address_col]):
    if pd.isna(addr):
        continue
    print(f"{i+1}/{len(df)} → {addr}")
    
    lat, lng = geocode(addr)
    df.at[i, "lat"] = lat
    df.at[i, "lng"] = lng

    time.sleep(0.2)   # API 호출 제한 방지

# 📌 결과를 새 엑셀로 저장
df.to_excel("output_with_latlng234.xlsx", index=False)

print("파일 저장 완료: output_with_latlng.xlsx")
# Out:
# 1/85 → 서울특별시 강남구 수서동 559
# 2/85 → 서울특별시 강서구 방화동 857
# 3/85 → 서울특별시 강서구 염창동 275-5
# 4/85 → 서울특별시 관악구 신림동 1644
# 5/85 → 서울특별시 광진구 자양동 658-14
# 6/85 → 서울특별시 도봉구 쌍문동 69-1
# 7/85 → 서울특별시 노원구 상계동 6013-15
# 8/85 → 서울특별시 강서구 방화동 182-44
# 9/85 → 서울특별시 강서구 방화동 863
# 10/85 → 서울특별시 노원구 공릉동 230
# 11/85 → 서울특별시 서대문구 북아현동 149
# 12/85 → 서울특별시 강남구 율현동 8
# 13/85 → 서울특별시 강서구 방화동 168-38
# 14/85 → 서울특별시 관악구 신림동 28-9
# 15/85 → 서울특별시 강서구 방화동 890
# 16/85 → 서울특별시 서초구 신원동 690
# 17/85 → 서울특별시 서초구 반포동 1-15
# 18/85 → 서울특별시 노원구 상계동 109-5
# 19/85 → 서울특별시 강남구 자곡동 4
# 20/85 → 서울특별시 강서구 방화동 201-1
# 21/85 → 서울특별시 동작구 사당동 25-2
# 22/85 → 서울특별시 강남구 일원동 690-1
# 23/85 → 서울특별시 강서구 방화동 883
# 24/85 → 서울특별시 강서구 방화동 859
# 25/85 → 서울특별시 서초구 잠원동 74-1
# 26/85 → 서울특별시 성북구 청량리동 949
# 27/85 → 서울특별시 강서구 방화동 207-5
# 28/85 → 서울특별시 강서구 방화동 884
# 29/85 → 서울특별시 강서구 방화동 892
# 30/85 → 서울특별시 동작구 봉천동 729-24
# 31/85 → 서울특별시 서초구 잠원동 52-2
# 32/85 → 서울특별시 강서구 방화동 876
# 33/85 → 서울특별시 강남구 삼성동 19-4
# 34/85 → 서울특별시 용산구 효창동 3-197
# 35/85 → 서울특별시 강서구 방화동 168-114
# 36/85 → 서울특별시 강서구 방화동 897
# 37/85 → 서울특별시 서초구 잠원동 74
# 38/85 → 서울특별시 강서구 방화동 888
# 39/85 → 서울특별시 성북구 길음동 973-2
# 40/85 → 서울특별시 구로구 구로동 685-280
# 41/85 → 서울특별시 강남구 역삼동 712
# 42/85 → 서울특별시 서초구 반포동 1-23
# 43/85 → 서울특별시 강동구 상일동 134
# 44/85 → 서울특별시 서초구 서초동 1335
# 45/85 → 서울특별시 중구 만리동2가 176-1
# 46/85 → 서울특별시 강동구 상일동 124
# 47/85 → 서울특별시 성동구 금호동1가 280
# 48/85 → 서울특별시 송파구 거여동 199-2
# 49/85 → 서울특별시 은평구 증산동 213-20
# 50/85 → 서울특별시 서초구 반포동 32-8
# 51/85 → 서울특별시 강남구 수서동 537
# 52/85 → 서울특별시 서초구 내곡동 0
# 53/85 → 서울특별시 성북구 장위동 173-114
# 54/85 → 서울특별시 강남구 자곡동 0
# 55/85 → 서울특별시 강남구 개포동 138
# 56/85 → 서울특별시 구로구 항동 238
# 57/85 → 서울특별시 성북구 장위동 144-24
# 58/85 → 서울특별시 노원구 상계동 6040-35
# 59/85 → 서울특별시 성북구 길음동 498
# 60/85 → 서울특별시 동작구 상도동 36-1
# 61/85 → 서울특별시 마포구 창전동 27-19
# 62/85 → 서울특별시 구로구 항동 0
# 63/85 → 서울특별시 송파구 가락동 479
# 64/85 → 서울특별시 용산구 공덕동 11-168
# 65/85 → 서울특별시 서대문구 길동 103-5
# 66/85 → 서울특별시 강남구 일원동 611-1
# 67/85 → 서울특별시 관악구 사당동 1152
# 68/85 → 서울특별시 중랑구 면목동 164-10
# 69/85 → 서울특별시 서대문구 남가좌동 286-1
# 70/85 → 서울특별시 서대문구 홍제동 270-1
# 71/85 → 서울특별시 강서구 방화동 905
# 72/85 → 서울특별시 구로구 고척동 97
# 73/85 → 서울특별시 강서구 화곡동 1027-50
# 74/85 → 서울특별시 서대문구 홍은동 338-5
# 75/85 → 서울특별시 강남구 대치동 977
# 76/85 → 서울특별시 중랑구 면목동 55-14
# 77/85 → 서울특별시 동작구 봉천동 1000
# 78/85 → 서울특별시 동대문구 용두동 39-1
# 79/85 → 서울특별시 강서구 방화동 1467
# 80/85 → 서울특별시 강서구 방화동 1252
# 81/85 → 서울특별시 강서구 방화동 1454
# 82/85 → 서울특별시 강서구 방화동 1181
# 83/85 → 서울특별시 강서구 방화동 1171
# 84/85 → 서울특별시 강서구 방화동 1525
# 85/85 → 서울특별시 중랑구 신내동 488
# 파일 저장 완료: output_with_latlng.xlsx

# %%
import pandas as pd
import requests
import time

# 🔑 카카오 REST API 키
REST_API_KEY = "YOUR_REST_API_KEY"

def geocode(query):
    """카카오 API로 주소 검색 → 위도/경도 + 전체 주소 반환"""
    url = "https://dapi.kakao.com/v2/local/search/address.json"
    headers = {"Authorization": f"KakaoAK {"개인 API여서 비공개하겠음"}"}
    params = {"query": query}

    try:
        response = requests.get(url, headers=headers, params=params, timeout=5)
        response.raise_for_status()
        data = response.json()
    except Exception as e:
        print(" ❌ API 요청 오류:", e)
        return None, None, None

    if data.get("documents"):
        doc = data["documents"][0]
        addr_info = doc.get("road_address") or doc.get("address")
        if addr_info:
            lng = addr_info["x"]
            lat = addr_info["y"]
            full_addr = addr_info["address_name"]
            return float(lat), float(lng), full_addr
    return None, None, None


# 📌 엑셀 불러오기
df = pd.read_excel(r"C:\Users\KimGW\Desktop\output_with_latlng1.xlsx")

# 📌 컬럼 정의
address_col = "주소"
city_col = "시명"
district_col = "자치구명"
dong_col = "법정동명"
building_col = "건물명"


# 👉 기존 lat/lng 없는 행만 처리
for i, row in df.iterrows():

    # 이미 처리된 행은 건너뛰기
    if pd.notna(row.get("lat")) and pd.notna(row.get("lng")):
        print(f"{i+1}/{len(df)} → 이미 처리됨, SKIP")
        continue

    original_addr = row[address_col]
    print(f"\n▶ {i+1}/{len(df)} — 주소 검색: {original_addr}")

    # 1) 기존 주소로 검색
    lat, lng, new_addr = geocode(original_addr)

    # 2) 기존 주소 실패 → 시명 + 자치구명 + 법정동명 + 건물명으로 검색
    if lat is None or lng is None:
        query2 = f"{row[city_col]} {row[district_col]} {row[dong_col]} {row[building_col]}"
        print(f"   ❗ 1차 실패 → 재검색: {query2}")
        lat, lng, new_addr = geocode(query2)

    # 3) 그래도 실패 → 건너뜀
    if lat is None or lng is None:
        print("   ❌ 최종 실패 → lat/lng 기록 안 함")
        continue

    # 4) 성공 → 값 기록 (주소 컬럼 덮어쓰기)
    df.at[i, address_col] = new_addr
    df.at[i, "lat"] = lat
    df.at[i, "lng"] = lng

    print(f"   ✅ 성공 → 주소 업데이트: {new_addr} / 좌표: ({lat}, {lng})")

    time.sleep(0.2)


# 📌 저장
df.to_excel("output_with_latlng.xlsx", index=False)
print("\n🎉 처리 완료 → output_with_latlng.xlsx 저장됨!")
# Out:
# 1/8597 → 이미 처리됨, SKIP
# 2/8597 → 이미 처리됨, SKIP
# 3/8597 → 이미 처리됨, SKIP
# 4/8597 → 이미 처리됨, SKIP
# 5/8597 → 이미 처리됨, SKIP
# 6/8597 → 이미 처리됨, SKIP
# 7/8597 → 이미 처리됨, SKIP
# 8/8597 → 이미 처리됨, SKIP
# 9/8597 → 이미 처리됨, SKIP
# 10/8597 → 이미 처리됨, SKIP
# 11/8597 → 이미 처리됨, SKIP
# 12/8597 → 이미 처리됨, SKIP
# 13/8597 → 이미 처리됨, SKIP
# 14/8597 → 이미 처리됨, SKIP
# 15/8597 → 이미 처리됨, SKIP
# 16/8597 → 이미 처리됨, SKIP
# 17/8597 → 이미 처리됨, SKIP
# 18/8597 → 이미 처리됨, SKIP
# 19/8597 → 이미 처리됨, SKIP
# 20/8597 → 이미 처리됨, SKIP
# 21/8597 → 이미 처리됨, SKIP
# 22/8597 → 이미 처리됨, SKIP
# 23/8597 → 이미 처리됨, SKIP
# 24/8597 → 이미 처리됨, SKIP
# 25/8597 → 이미 처리됨, SKIP
# 26/8597 → 이미 처리됨, SKIP
# 27/8597 → 이미 처리됨, SKIP
# 28/8597 → 이미 처리됨, SKIP
# 29/8597 → 이미 처리됨, SKIP
# 30/8597 → 이미 처리됨, SKIP
# 31/8597 → 이미 처리됨, SKIP
# 32/8597 → 이미 처리됨, SKIP
# 33/8597 → 이미 처리됨, SKIP
#
# ▶ 34/8597 — 주소 검색: 서울특별시 강남구 수서동 559
#    ❗ 1차 실패 → 재검색: 서울특별시 강남구 수서동 강남데시앙포레
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 35/8597 → 이미 처리됨, SKIP
# 36/8597 → 이미 처리됨, SKIP
# 37/8597 → 이미 처리됨, SKIP
# 38/8597 → 이미 처리됨, SKIP
# 39/8597 → 이미 처리됨, SKIP
# 40/8597 → 이미 처리됨, SKIP
# 41/8597 → 이미 처리됨, SKIP
# 42/8597 → 이미 처리됨, SKIP
# 43/8597 → 이미 처리됨, SKIP
# 44/8597 → 이미 처리됨, SKIP
# 45/8597 → 이미 처리됨, SKIP
# 46/8597 → 이미 처리됨, SKIP
# 47/8597 → 이미 처리됨, SKIP
# 48/8597 → 이미 처리됨, SKIP
# 49/8597 → 이미 처리됨, SKIP
# 50/8597 → 이미 처리됨, SKIP
# 51/8597 → 이미 처리됨, SKIP
# 52/8597 → 이미 처리됨, SKIP
# 53/8597 → 이미 처리됨, SKIP
# 54/8597 → 이미 처리됨, SKIP
# 55/8597 → 이미 처리됨, SKIP
# 56/8597 → 이미 처리됨, SKIP
# 57/8597 → 이미 처리됨, SKIP
# 58/8597 → 이미 처리됨, SKIP
# 59/8597 → 이미 처리됨, SKIP
# 60/8597 → 이미 처리됨, SKIP
#
# ▶ 61/8597 — 주소 검색: 서울특별시 강서구 방화동 857
#    ❗ 1차 실패 → 재검색: 서울특별시 강서구 방화동 마곡삼성아파트
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 62/8597 → 이미 처리됨, SKIP
# 63/8597 → 이미 처리됨, SKIP
# 64/8597 → 이미 처리됨, SKIP
# 65/8597 → 이미 처리됨, SKIP
# 66/8597 → 이미 처리됨, SKIP
# 67/8597 → 이미 처리됨, SKIP
# 68/8597 → 이미 처리됨, SKIP
# 69/8597 → 이미 처리됨, SKIP
# 70/8597 → 이미 처리됨, SKIP
# 71/8597 → 이미 처리됨, SKIP
# 72/8597 → 이미 처리됨, SKIP
# 73/8597 → 이미 처리됨, SKIP
# 74/8597 → 이미 처리됨, SKIP
# 75/8597 → 이미 처리됨, SKIP
# 76/8597 → 이미 처리됨, SKIP
# 77/8597 → 이미 처리됨, SKIP
# 78/8597 → 이미 처리됨, SKIP
# 79/8597 → 이미 처리됨, SKIP
# 80/8597 → 이미 처리됨, SKIP
# 81/8597 → 이미 처리됨, SKIP
# 82/8597 → 이미 처리됨, SKIP
# 83/8597 → 이미 처리됨, SKIP
# 84/8597 → 이미 처리됨, SKIP
# 85/8597 → 이미 처리됨, SKIP
# 86/8597 → 이미 처리됨, SKIP
# 87/8597 → 이미 처리됨, SKIP
# 88/8597 → 이미 처리됨, SKIP
# 89/8597 → 이미 처리됨, SKIP
# 90/8597 → 이미 처리됨, SKIP
# 91/8597 → 이미 처리됨, SKIP
# 92/8597 → 이미 처리됨, SKIP
# 93/8597 → 이미 처리됨, SKIP
# 94/8597 → 이미 처리됨, SKIP
# 95/8597 → 이미 처리됨, SKIP
# 96/8597 → 이미 처리됨, SKIP
# 97/8597 → 이미 처리됨, SKIP
# 98/8597 → 이미 처리됨, SKIP
#
# ▶ 99/8597 — 주소 검색: 서울특별시 강서구 염창동 275-5
#    ❗ 1차 실패 → 재검색: 서울특별시 강서구 염창동 등마루
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 100/8597 → 이미 처리됨, SKIP
# 101/8597 → 이미 처리됨, SKIP
# 102/8597 → 이미 처리됨, SKIP
# 103/8597 → 이미 처리됨, SKIP
# 104/8597 → 이미 처리됨, SKIP
# 105/8597 → 이미 처리됨, SKIP
# 106/8597 → 이미 처리됨, SKIP
# 107/8597 → 이미 처리됨, SKIP
# 108/8597 → 이미 처리됨, SKIP
# 109/8597 → 이미 처리됨, SKIP
# 110/8597 → 이미 처리됨, SKIP
# 111/8597 → 이미 처리됨, SKIP
# 112/8597 → 이미 처리됨, SKIP
# 113/8597 → 이미 처리됨, SKIP
# 114/8597 → 이미 처리됨, SKIP
# 115/8597 → 이미 처리됨, SKIP
# 116/8597 → 이미 처리됨, SKIP
# 117/8597 → 이미 처리됨, SKIP
# 118/8597 → 이미 처리됨, SKIP
# 119/8597 → 이미 처리됨, SKIP
# 120/8597 → 이미 처리됨, SKIP
# 121/8597 → 이미 처리됨, SKIP
# 122/8597 → 이미 처리됨, SKIP
# 123/8597 → 이미 처리됨, SKIP
# 124/8597 → 이미 처리됨, SKIP
# 125/8597 → 이미 처리됨, SKIP
# 126/8597 → 이미 처리됨, SKIP
# 127/8597 → 이미 처리됨, SKIP
# 128/8597 → 이미 처리됨, SKIP
# 129/8597 → 이미 처리됨, SKIP
# 130/8597 → 이미 처리됨, SKIP
# 131/8597 → 이미 처리됨, SKIP
# 132/8597 → 이미 처리됨, SKIP
# 133/8597 → 이미 처리됨, SKIP
# 134/8597 → 이미 처리됨, SKIP
# 135/8597 → 이미 처리됨, SKIP
# 136/8597 → 이미 처리됨, SKIP
# 137/8597 → 이미 처리됨, SKIP
# 138/8597 → 이미 처리됨, SKIP
# 139/8597 → 이미 처리됨, SKIP
# 140/8597 → 이미 처리됨, SKIP
# 141/8597 → 이미 처리됨, SKIP
# 142/8597 → 이미 처리됨, SKIP
# 143/8597 → 이미 처리됨, SKIP
# 144/8597 → 이미 처리됨, SKIP
# 145/8597 → 이미 처리됨, SKIP
# 146/8597 → 이미 처리됨, SKIP
# 147/8597 → 이미 처리됨, SKIP
# 148/8597 → 이미 처리됨, SKIP
# 149/8597 → 이미 처리됨, SKIP
# 150/8597 → 이미 처리됨, SKIP
# 151/8597 → 이미 처리됨, SKIP
# 152/8597 → 이미 처리됨, SKIP
# 153/8597 → 이미 처리됨, SKIP
# 154/8597 → 이미 처리됨, SKIP
# 155/8597 → 이미 처리됨, SKIP
# 156/8597 → 이미 처리됨, SKIP
# 157/8597 → 이미 처리됨, SKIP
# 158/8597 → 이미 처리됨, SKIP
# 159/8597 → 이미 처리됨, SKIP
# 160/8597 → 이미 처리됨, SKIP
# 161/8597 → 이미 처리됨, SKIP
# 162/8597 → 이미 처리됨, SKIP
# 163/8597 → 이미 처리됨, SKIP
# 164/8597 → 이미 처리됨, SKIP
# 165/8597 → 이미 처리됨, SKIP
# 166/8597 → 이미 처리됨, SKIP
# 167/8597 → 이미 처리됨, SKIP
# 168/8597 → 이미 처리됨, SKIP
# 169/8597 → 이미 처리됨, SKIP
# 170/8597 → 이미 처리됨, SKIP
# 171/8597 → 이미 처리됨, SKIP
# 172/8597 → 이미 처리됨, SKIP
# 173/8597 → 이미 처리됨, SKIP
# 174/8597 → 이미 처리됨, SKIP
# 175/8597 → 이미 처리됨, SKIP
# 176/8597 → 이미 처리됨, SKIP
# 177/8597 → 이미 처리됨, SKIP
# 178/8597 → 이미 처리됨, SKIP
# 179/8597 → 이미 처리됨, SKIP
# 180/8597 → 이미 처리됨, SKIP
# 181/8597 → 이미 처리됨, SKIP
# 182/8597 → 이미 처리됨, SKIP
# 183/8597 → 이미 처리됨, SKIP
# 184/8597 → 이미 처리됨, SKIP
# 185/8597 → 이미 처리됨, SKIP
# 186/8597 → 이미 처리됨, SKIP
# 187/8597 → 이미 처리됨, SKIP
# 188/8597 → 이미 처리됨, SKIP
# 189/8597 → 이미 처리됨, SKIP
# 190/8597 → 이미 처리됨, SKIP
# 191/8597 → 이미 처리됨, SKIP
# 192/8597 → 이미 처리됨, SKIP
# 193/8597 → 이미 처리됨, SKIP
# 194/8597 → 이미 처리됨, SKIP
# 195/8597 → 이미 처리됨, SKIP
# 196/8597 → 이미 처리됨, SKIP
# 197/8597 → 이미 처리됨, SKIP
# 198/8597 → 이미 처리됨, SKIP
# 199/8597 → 이미 처리됨, SKIP
# 200/8597 → 이미 처리됨, SKIP
# 201/8597 → 이미 처리됨, SKIP
# 202/8597 → 이미 처리됨, SKIP
# 203/8597 → 이미 처리됨, SKIP
# 204/8597 → 이미 처리됨, SKIP
# 205/8597 → 이미 처리됨, SKIP
# 206/8597 → 이미 처리됨, SKIP
# 207/8597 → 이미 처리됨, SKIP
# 208/8597 → 이미 처리됨, SKIP
# 209/8597 → 이미 처리됨, SKIP
# 210/8597 → 이미 처리됨, SKIP
# 211/8597 → 이미 처리됨, SKIP
# 212/8597 → 이미 처리됨, SKIP
# 213/8597 → 이미 처리됨, SKIP
# 214/8597 → 이미 처리됨, SKIP
# 215/8597 → 이미 처리됨, SKIP
# 216/8597 → 이미 처리됨, SKIP
# 217/8597 → 이미 처리됨, SKIP
# 218/8597 → 이미 처리됨, SKIP
# 219/8597 → 이미 처리됨, SKIP
# 220/8597 → 이미 처리됨, SKIP
# 221/8597 → 이미 처리됨, SKIP
# 222/8597 → 이미 처리됨, SKIP
# 223/8597 → 이미 처리됨, SKIP
# 224/8597 → 이미 처리됨, SKIP
# 225/8597 → 이미 처리됨, SKIP
# 226/8597 → 이미 처리됨, SKIP
# 227/8597 → 이미 처리됨, SKIP
# 228/8597 → 이미 처리됨, SKIP
# 229/8597 → 이미 처리됨, SKIP
# 230/8597 → 이미 처리됨, SKIP
# 231/8597 → 이미 처리됨, SKIP
# 232/8597 → 이미 처리됨, SKIP
# 233/8597 → 이미 처리됨, SKIP
# 234/8597 → 이미 처리됨, SKIP
# 235/8597 → 이미 처리됨, SKIP
# 236/8597 → 이미 처리됨, SKIP
# 237/8597 → 이미 처리됨, SKIP
# 238/8597 → 이미 처리됨, SKIP
# 239/8597 → 이미 처리됨, SKIP
# 240/8597 → 이미 처리됨, SKIP
# 241/8597 → 이미 처리됨, SKIP
# 242/8597 → 이미 처리됨, SKIP
# 243/8597 → 이미 처리됨, SKIP
# 244/8597 → 이미 처리됨, SKIP
# 245/8597 → 이미 처리됨, SKIP
# 246/8597 → 이미 처리됨, SKIP
# 247/8597 → 이미 처리됨, SKIP
# 248/8597 → 이미 처리됨, SKIP
# 249/8597 → 이미 처리됨, SKIP
# 250/8597 → 이미 처리됨, SKIP
# 251/8597 → 이미 처리됨, SKIP
# 252/8597 → 이미 처리됨, SKIP
# 253/8597 → 이미 처리됨, SKIP
# 254/8597 → 이미 처리됨, SKIP
# 255/8597 → 이미 처리됨, SKIP
# 256/8597 → 이미 처리됨, SKIP
# 257/8597 → 이미 처리됨, SKIP
# 258/8597 → 이미 처리됨, SKIP
# 259/8597 → 이미 처리됨, SKIP
# 260/8597 → 이미 처리됨, SKIP
# 261/8597 → 이미 처리됨, SKIP
# 262/8597 → 이미 처리됨, SKIP
# 263/8597 → 이미 처리됨, SKIP
# 264/8597 → 이미 처리됨, SKIP
# 265/8597 → 이미 처리됨, SKIP
# 266/8597 → 이미 처리됨, SKIP
# 267/8597 → 이미 처리됨, SKIP
# 268/8597 → 이미 처리됨, SKIP
# 269/8597 → 이미 처리됨, SKIP
# 270/8597 → 이미 처리됨, SKIP
# 271/8597 → 이미 처리됨, SKIP
# 272/8597 → 이미 처리됨, SKIP
# 273/8597 → 이미 처리됨, SKIP
# 274/8597 → 이미 처리됨, SKIP
# 275/8597 → 이미 처리됨, SKIP
# 276/8597 → 이미 처리됨, SKIP
# 277/8597 → 이미 처리됨, SKIP
#
# ▶ 278/8597 — 주소 검색: 서울특별시 관악구 신림동 1644
#    ❗ 1차 실패 → 재검색: 서울특별시 관악구 신림동 강남
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 279/8597 → 이미 처리됨, SKIP
# 280/8597 → 이미 처리됨, SKIP
# 281/8597 → 이미 처리됨, SKIP
# 282/8597 → 이미 처리됨, SKIP
# 283/8597 → 이미 처리됨, SKIP
# 284/8597 → 이미 처리됨, SKIP
# 285/8597 → 이미 처리됨, SKIP
# 286/8597 → 이미 처리됨, SKIP
# 287/8597 → 이미 처리됨, SKIP
# 288/8597 → 이미 처리됨, SKIP
# 289/8597 → 이미 처리됨, SKIP
# 290/8597 → 이미 처리됨, SKIP
# 291/8597 → 이미 처리됨, SKIP
# 292/8597 → 이미 처리됨, SKIP
# 293/8597 → 이미 처리됨, SKIP
# 294/8597 → 이미 처리됨, SKIP
# 295/8597 → 이미 처리됨, SKIP
# 296/8597 → 이미 처리됨, SKIP
# 297/8597 → 이미 처리됨, SKIP
# 298/8597 → 이미 처리됨, SKIP
# 299/8597 → 이미 처리됨, SKIP
# 300/8597 → 이미 처리됨, SKIP
# 301/8597 → 이미 처리됨, SKIP
# 302/8597 → 이미 처리됨, SKIP
# 303/8597 → 이미 처리됨, SKIP
# 304/8597 → 이미 처리됨, SKIP
# 305/8597 → 이미 처리됨, SKIP
# 306/8597 → 이미 처리됨, SKIP
# 307/8597 → 이미 처리됨, SKIP
# 308/8597 → 이미 처리됨, SKIP
# 309/8597 → 이미 처리됨, SKIP
# 310/8597 → 이미 처리됨, SKIP
# 311/8597 → 이미 처리됨, SKIP
# 312/8597 → 이미 처리됨, SKIP
# 313/8597 → 이미 처리됨, SKIP
# 314/8597 → 이미 처리됨, SKIP
# 315/8597 → 이미 처리됨, SKIP
# 316/8597 → 이미 처리됨, SKIP
# 317/8597 → 이미 처리됨, SKIP
# 318/8597 → 이미 처리됨, SKIP
# 319/8597 → 이미 처리됨, SKIP
# 320/8597 → 이미 처리됨, SKIP
# 321/8597 → 이미 처리됨, SKIP
# 322/8597 → 이미 처리됨, SKIP
# 323/8597 → 이미 처리됨, SKIP
# 324/8597 → 이미 처리됨, SKIP
# 325/8597 → 이미 처리됨, SKIP
# 326/8597 → 이미 처리됨, SKIP
# 327/8597 → 이미 처리됨, SKIP
# 328/8597 → 이미 처리됨, SKIP
# 329/8597 → 이미 처리됨, SKIP
# 330/8597 → 이미 처리됨, SKIP
# 331/8597 → 이미 처리됨, SKIP
# 332/8597 → 이미 처리됨, SKIP
# 333/8597 → 이미 처리됨, SKIP
# 334/8597 → 이미 처리됨, SKIP
# 335/8597 → 이미 처리됨, SKIP
# 336/8597 → 이미 처리됨, SKIP
# 337/8597 → 이미 처리됨, SKIP
# 338/8597 → 이미 처리됨, SKIP
# 339/8597 → 이미 처리됨, SKIP
# 340/8597 → 이미 처리됨, SKIP
# 341/8597 → 이미 처리됨, SKIP
# 342/8597 → 이미 처리됨, SKIP
# 343/8597 → 이미 처리됨, SKIP
# 344/8597 → 이미 처리됨, SKIP
# 345/8597 → 이미 처리됨, SKIP
# 346/8597 → 이미 처리됨, SKIP
# 347/8597 → 이미 처리됨, SKIP
# 348/8597 → 이미 처리됨, SKIP
# 349/8597 → 이미 처리됨, SKIP
# 350/8597 → 이미 처리됨, SKIP
# 351/8597 → 이미 처리됨, SKIP
# 352/8597 → 이미 처리됨, SKIP
# 353/8597 → 이미 처리됨, SKIP
# 354/8597 → 이미 처리됨, SKIP
# 355/8597 → 이미 처리됨, SKIP
#
# ▶ 356/8597 — 주소 검색: 서울특별시 광진구 자양동 658-14
#    ❗ 1차 실패 → 재검색: 서울특별시 광진구 자양동 자양
#    ✅ 성공 → 주소 업데이트: 서울 광진구 자양동 / 좌표: (37.5311077958687, 127.073018338792)
# 357/8597 → 이미 처리됨, SKIP
# 358/8597 → 이미 처리됨, SKIP
# 359/8597 → 이미 처리됨, SKIP
# 360/8597 → 이미 처리됨, SKIP
# 361/8597 → 이미 처리됨, SKIP
# 362/8597 → 이미 처리됨, SKIP
# 363/8597 → 이미 처리됨, SKIP
# 364/8597 → 이미 처리됨, SKIP
# 365/8597 → 이미 처리됨, SKIP
# 366/8597 → 이미 처리됨, SKIP
# 367/8597 → 이미 처리됨, SKIP
# 368/8597 → 이미 처리됨, SKIP
# 369/8597 → 이미 처리됨, SKIP
# 370/8597 → 이미 처리됨, SKIP
# 371/8597 → 이미 처리됨, SKIP
# 372/8597 → 이미 처리됨, SKIP
# 373/8597 → 이미 처리됨, SKIP
# 374/8597 → 이미 처리됨, SKIP
# 375/8597 → 이미 처리됨, SKIP
# 376/8597 → 이미 처리됨, SKIP
# 377/8597 → 이미 처리됨, SKIP
# 378/8597 → 이미 처리됨, SKIP
# 379/8597 → 이미 처리됨, SKIP
# 380/8597 → 이미 처리됨, SKIP
# 381/8597 → 이미 처리됨, SKIP
# 382/8597 → 이미 처리됨, SKIP
# 383/8597 → 이미 처리됨, SKIP
# 384/8597 → 이미 처리됨, SKIP
# 385/8597 → 이미 처리됨, SKIP
# 386/8597 → 이미 처리됨, SKIP
# 387/8597 → 이미 처리됨, SKIP
# 388/8597 → 이미 처리됨, SKIP
# 389/8597 → 이미 처리됨, SKIP
# 390/8597 → 이미 처리됨, SKIP
# 391/8597 → 이미 처리됨, SKIP
# 392/8597 → 이미 처리됨, SKIP
# 393/8597 → 이미 처리됨, SKIP
# 394/8597 → 이미 처리됨, SKIP
# 395/8597 → 이미 처리됨, SKIP
# 396/8597 → 이미 처리됨, SKIP
# 397/8597 → 이미 처리됨, SKIP
# 398/8597 → 이미 처리됨, SKIP
# 399/8597 → 이미 처리됨, SKIP
# 400/8597 → 이미 처리됨, SKIP
# 401/8597 → 이미 처리됨, SKIP
# 402/8597 → 이미 처리됨, SKIP
# 403/8597 → 이미 처리됨, SKIP
# 404/8597 → 이미 처리됨, SKIP
# 405/8597 → 이미 처리됨, SKIP
# 406/8597 → 이미 처리됨, SKIP
# 407/8597 → 이미 처리됨, SKIP
# 408/8597 → 이미 처리됨, SKIP
# 409/8597 → 이미 처리됨, SKIP
# 410/8597 → 이미 처리됨, SKIP
# 411/8597 → 이미 처리됨, SKIP
# 412/8597 → 이미 처리됨, SKIP
# 413/8597 → 이미 처리됨, SKIP
# 414/8597 → 이미 처리됨, SKIP
# 415/8597 → 이미 처리됨, SKIP
# 416/8597 → 이미 처리됨, SKIP
# 417/8597 → 이미 처리됨, SKIP
# 418/8597 → 이미 처리됨, SKIP
# 419/8597 → 이미 처리됨, SKIP
# 420/8597 → 이미 처리됨, SKIP
# 421/8597 → 이미 처리됨, SKIP
# 422/8597 → 이미 처리됨, SKIP
# 423/8597 → 이미 처리됨, SKIP
# 424/8597 → 이미 처리됨, SKIP
# 425/8597 → 이미 처리됨, SKIP
# 426/8597 → 이미 처리됨, SKIP
# 427/8597 → 이미 처리됨, SKIP
# 428/8597 → 이미 처리됨, SKIP
# 429/8597 → 이미 처리됨, SKIP
# 430/8597 → 이미 처리됨, SKIP
# 431/8597 → 이미 처리됨, SKIP
# 432/8597 → 이미 처리됨, SKIP
# 433/8597 → 이미 처리됨, SKIP
# 434/8597 → 이미 처리됨, SKIP
# 435/8597 → 이미 처리됨, SKIP
# 436/8597 → 이미 처리됨, SKIP
# 437/8597 → 이미 처리됨, SKIP
# 438/8597 → 이미 처리됨, SKIP
# 439/8597 → 이미 처리됨, SKIP
# 440/8597 → 이미 처리됨, SKIP
# 441/8597 → 이미 처리됨, SKIP
# 442/8597 → 이미 처리됨, SKIP
# 443/8597 → 이미 처리됨, SKIP
# 444/8597 → 이미 처리됨, SKIP
# 445/8597 → 이미 처리됨, SKIP
# 446/8597 → 이미 처리됨, SKIP
# 447/8597 → 이미 처리됨, SKIP
# 448/8597 → 이미 처리됨, SKIP
# 449/8597 → 이미 처리됨, SKIP
# 450/8597 → 이미 처리됨, SKIP
# 451/8597 → 이미 처리됨, SKIP
# 452/8597 → 이미 처리됨, SKIP
# 453/8597 → 이미 처리됨, SKIP
# 454/8597 → 이미 처리됨, SKIP
# 455/8597 → 이미 처리됨, SKIP
# 456/8597 → 이미 처리됨, SKIP
# 457/8597 → 이미 처리됨, SKIP
# 458/8597 → 이미 처리됨, SKIP
# 459/8597 → 이미 처리됨, SKIP
# 460/8597 → 이미 처리됨, SKIP
# 461/8597 → 이미 처리됨, SKIP
# 462/8597 → 이미 처리됨, SKIP
# 463/8597 → 이미 처리됨, SKIP
# 464/8597 → 이미 처리됨, SKIP
# 465/8597 → 이미 처리됨, SKIP
# 466/8597 → 이미 처리됨, SKIP
# 467/8597 → 이미 처리됨, SKIP
# 468/8597 → 이미 처리됨, SKIP
# 469/8597 → 이미 처리됨, SKIP
# 470/8597 → 이미 처리됨, SKIP
# 471/8597 → 이미 처리됨, SKIP
# 472/8597 → 이미 처리됨, SKIP
# 473/8597 → 이미 처리됨, SKIP
# 474/8597 → 이미 처리됨, SKIP
# 475/8597 → 이미 처리됨, SKIP
# 476/8597 → 이미 처리됨, SKIP
# 477/8597 → 이미 처리됨, SKIP
# 478/8597 → 이미 처리됨, SKIP
# 479/8597 → 이미 처리됨, SKIP
# 480/8597 → 이미 처리됨, SKIP
# 481/8597 → 이미 처리됨, SKIP
# 482/8597 → 이미 처리됨, SKIP
# 483/8597 → 이미 처리됨, SKIP
# 484/8597 → 이미 처리됨, SKIP
# 485/8597 → 이미 처리됨, SKIP
# 486/8597 → 이미 처리됨, SKIP
# 487/8597 → 이미 처리됨, SKIP
# 488/8597 → 이미 처리됨, SKIP
# 489/8597 → 이미 처리됨, SKIP
# 490/8597 → 이미 처리됨, SKIP
# 491/8597 → 이미 처리됨, SKIP
# 492/8597 → 이미 처리됨, SKIP
# 493/8597 → 이미 처리됨, SKIP
# 494/8597 → 이미 처리됨, SKIP
# 495/8597 → 이미 처리됨, SKIP
# 496/8597 → 이미 처리됨, SKIP
# 497/8597 → 이미 처리됨, SKIP
# 498/8597 → 이미 처리됨, SKIP
# 499/8597 → 이미 처리됨, SKIP
# 500/8597 → 이미 처리됨, SKIP
# 501/8597 → 이미 처리됨, SKIP
# 502/8597 → 이미 처리됨, SKIP
# 503/8597 → 이미 처리됨, SKIP
# 504/8597 → 이미 처리됨, SKIP
# 505/8597 → 이미 처리됨, SKIP
# 506/8597 → 이미 처리됨, SKIP
# 507/8597 → 이미 처리됨, SKIP
# 508/8597 → 이미 처리됨, SKIP
# 509/8597 → 이미 처리됨, SKIP
# 510/8597 → 이미 처리됨, SKIP
# 511/8597 → 이미 처리됨, SKIP
# 512/8597 → 이미 처리됨, SKIP
# 513/8597 → 이미 처리됨, SKIP
# 514/8597 → 이미 처리됨, SKIP
# 515/8597 → 이미 처리됨, SKIP
# 516/8597 → 이미 처리됨, SKIP
# 517/8597 → 이미 처리됨, SKIP
# 518/8597 → 이미 처리됨, SKIP
# 519/8597 → 이미 처리됨, SKIP
# 520/8597 → 이미 처리됨, SKIP
# 521/8597 → 이미 처리됨, SKIP
# 522/8597 → 이미 처리됨, SKIP
# 523/8597 → 이미 처리됨, SKIP
# 524/8597 → 이미 처리됨, SKIP
# 525/8597 → 이미 처리됨, SKIP
# 526/8597 → 이미 처리됨, SKIP
# 527/8597 → 이미 처리됨, SKIP
# 528/8597 → 이미 처리됨, SKIP
# 529/8597 → 이미 처리됨, SKIP
# 530/8597 → 이미 처리됨, SKIP
# 531/8597 → 이미 처리됨, SKIP
# 532/8597 → 이미 처리됨, SKIP
# 533/8597 → 이미 처리됨, SKIP
# 534/8597 → 이미 처리됨, SKIP
# 535/8597 → 이미 처리됨, SKIP
# 536/8597 → 이미 처리됨, SKIP
# 537/8597 → 이미 처리됨, SKIP
# 538/8597 → 이미 처리됨, SKIP
# 539/8597 → 이미 처리됨, SKIP
# 540/8597 → 이미 처리됨, SKIP
# 541/8597 → 이미 처리됨, SKIP
# 542/8597 → 이미 처리됨, SKIP
# 543/8597 → 이미 처리됨, SKIP
# 544/8597 → 이미 처리됨, SKIP
# 545/8597 → 이미 처리됨, SKIP
# 546/8597 → 이미 처리됨, SKIP
# 547/8597 → 이미 처리됨, SKIP
# 548/8597 → 이미 처리됨, SKIP
# 549/8597 → 이미 처리됨, SKIP
# 550/8597 → 이미 처리됨, SKIP
# 551/8597 → 이미 처리됨, SKIP
# 552/8597 → 이미 처리됨, SKIP
# 553/8597 → 이미 처리됨, SKIP
# 554/8597 → 이미 처리됨, SKIP
# 555/8597 → 이미 처리됨, SKIP
# 556/8597 → 이미 처리됨, SKIP
# 557/8597 → 이미 처리됨, SKIP
# 558/8597 → 이미 처리됨, SKIP
# 559/8597 → 이미 처리됨, SKIP
# 560/8597 → 이미 처리됨, SKIP
# 561/8597 → 이미 처리됨, SKIP
# 562/8597 → 이미 처리됨, SKIP
# 563/8597 → 이미 처리됨, SKIP
# 564/8597 → 이미 처리됨, SKIP
# 565/8597 → 이미 처리됨, SKIP
# 566/8597 → 이미 처리됨, SKIP
# 567/8597 → 이미 처리됨, SKIP
# 568/8597 → 이미 처리됨, SKIP
# 569/8597 → 이미 처리됨, SKIP
# 570/8597 → 이미 처리됨, SKIP
# 571/8597 → 이미 처리됨, SKIP
# 572/8597 → 이미 처리됨, SKIP
# 573/8597 → 이미 처리됨, SKIP
# 574/8597 → 이미 처리됨, SKIP
# 575/8597 → 이미 처리됨, SKIP
# 576/8597 → 이미 처리됨, SKIP
# 577/8597 → 이미 처리됨, SKIP
# 578/8597 → 이미 처리됨, SKIP
# 579/8597 → 이미 처리됨, SKIP
# 580/8597 → 이미 처리됨, SKIP
# 581/8597 → 이미 처리됨, SKIP
# 582/8597 → 이미 처리됨, SKIP
# 583/8597 → 이미 처리됨, SKIP
# 584/8597 → 이미 처리됨, SKIP
# 585/8597 → 이미 처리됨, SKIP
# 586/8597 → 이미 처리됨, SKIP
# 587/8597 → 이미 처리됨, SKIP
# 588/8597 → 이미 처리됨, SKIP
# 589/8597 → 이미 처리됨, SKIP
# 590/8597 → 이미 처리됨, SKIP
# 591/8597 → 이미 처리됨, SKIP
# 592/8597 → 이미 처리됨, SKIP
# 593/8597 → 이미 처리됨, SKIP
# 594/8597 → 이미 처리됨, SKIP
# 595/8597 → 이미 처리됨, SKIP
# 596/8597 → 이미 처리됨, SKIP
# 597/8597 → 이미 처리됨, SKIP
# 598/8597 → 이미 처리됨, SKIP
# 599/8597 → 이미 처리됨, SKIP
# 600/8597 → 이미 처리됨, SKIP
# 601/8597 → 이미 처리됨, SKIP
# 602/8597 → 이미 처리됨, SKIP
# 603/8597 → 이미 처리됨, SKIP
# 604/8597 → 이미 처리됨, SKIP
# 605/8597 → 이미 처리됨, SKIP
# 606/8597 → 이미 처리됨, SKIP
# 607/8597 → 이미 처리됨, SKIP
# 608/8597 → 이미 처리됨, SKIP
# 609/8597 → 이미 처리됨, SKIP
# 610/8597 → 이미 처리됨, SKIP
# 611/8597 → 이미 처리됨, SKIP
# 612/8597 → 이미 처리됨, SKIP
# 613/8597 → 이미 처리됨, SKIP
# 614/8597 → 이미 처리됨, SKIP
# 615/8597 → 이미 처리됨, SKIP
# 616/8597 → 이미 처리됨, SKIP
# 617/8597 → 이미 처리됨, SKIP
# 618/8597 → 이미 처리됨, SKIP
# 619/8597 → 이미 처리됨, SKIP
# 620/8597 → 이미 처리됨, SKIP
# 621/8597 → 이미 처리됨, SKIP
# 622/8597 → 이미 처리됨, SKIP
# 623/8597 → 이미 처리됨, SKIP
# 624/8597 → 이미 처리됨, SKIP
# 625/8597 → 이미 처리됨, SKIP
# 626/8597 → 이미 처리됨, SKIP
# 627/8597 → 이미 처리됨, SKIP
# 628/8597 → 이미 처리됨, SKIP
# 629/8597 → 이미 처리됨, SKIP
# 630/8597 → 이미 처리됨, SKIP
# 631/8597 → 이미 처리됨, SKIP
# 632/8597 → 이미 처리됨, SKIP
# 633/8597 → 이미 처리됨, SKIP
# 634/8597 → 이미 처리됨, SKIP
# 635/8597 → 이미 처리됨, SKIP
# 636/8597 → 이미 처리됨, SKIP
# 637/8597 → 이미 처리됨, SKIP
# 638/8597 → 이미 처리됨, SKIP
# 639/8597 → 이미 처리됨, SKIP
# 640/8597 → 이미 처리됨, SKIP
# 641/8597 → 이미 처리됨, SKIP
# 642/8597 → 이미 처리됨, SKIP
# 643/8597 → 이미 처리됨, SKIP
# 644/8597 → 이미 처리됨, SKIP
# 645/8597 → 이미 처리됨, SKIP
# 646/8597 → 이미 처리됨, SKIP
# 647/8597 → 이미 처리됨, SKIP
# 648/8597 → 이미 처리됨, SKIP
# 649/8597 → 이미 처리됨, SKIP
# 650/8597 → 이미 처리됨, SKIP
# 651/8597 → 이미 처리됨, SKIP
# 652/8597 → 이미 처리됨, SKIP
# 653/8597 → 이미 처리됨, SKIP
# 654/8597 → 이미 처리됨, SKIP
# 655/8597 → 이미 처리됨, SKIP
# 656/8597 → 이미 처리됨, SKIP
# 657/8597 → 이미 처리됨, SKIP
# 658/8597 → 이미 처리됨, SKIP
# 659/8597 → 이미 처리됨, SKIP
# 660/8597 → 이미 처리됨, SKIP
# 661/8597 → 이미 처리됨, SKIP
# 662/8597 → 이미 처리됨, SKIP
# 663/8597 → 이미 처리됨, SKIP
# 664/8597 → 이미 처리됨, SKIP
# 665/8597 → 이미 처리됨, SKIP
# 666/8597 → 이미 처리됨, SKIP
# 667/8597 → 이미 처리됨, SKIP
# 668/8597 → 이미 처리됨, SKIP
# 669/8597 → 이미 처리됨, SKIP
# 670/8597 → 이미 처리됨, SKIP
# 671/8597 → 이미 처리됨, SKIP
# 672/8597 → 이미 처리됨, SKIP
# 673/8597 → 이미 처리됨, SKIP
# 674/8597 → 이미 처리됨, SKIP
# 675/8597 → 이미 처리됨, SKIP
# 676/8597 → 이미 처리됨, SKIP
# 677/8597 → 이미 처리됨, SKIP
# 678/8597 → 이미 처리됨, SKIP
# 679/8597 → 이미 처리됨, SKIP
# 680/8597 → 이미 처리됨, SKIP
# 681/8597 → 이미 처리됨, SKIP
# 682/8597 → 이미 처리됨, SKIP
# 683/8597 → 이미 처리됨, SKIP
# 684/8597 → 이미 처리됨, SKIP
# 685/8597 → 이미 처리됨, SKIP
# 686/8597 → 이미 처리됨, SKIP
# 687/8597 → 이미 처리됨, SKIP
# 688/8597 → 이미 처리됨, SKIP
# 689/8597 → 이미 처리됨, SKIP
# 690/8597 → 이미 처리됨, SKIP
# 691/8597 → 이미 처리됨, SKIP
# 692/8597 → 이미 처리됨, SKIP
# 693/8597 → 이미 처리됨, SKIP
# 694/8597 → 이미 처리됨, SKIP
# 695/8597 → 이미 처리됨, SKIP
# 696/8597 → 이미 처리됨, SKIP
# 697/8597 → 이미 처리됨, SKIP
# 698/8597 → 이미 처리됨, SKIP
# 699/8597 → 이미 처리됨, SKIP
# 700/8597 → 이미 처리됨, SKIP
# 701/8597 → 이미 처리됨, SKIP
# 702/8597 → 이미 처리됨, SKIP
# 703/8597 → 이미 처리됨, SKIP
# 704/8597 → 이미 처리됨, SKIP
# 705/8597 → 이미 처리됨, SKIP
# 706/8597 → 이미 처리됨, SKIP
# 707/8597 → 이미 처리됨, SKIP
# 708/8597 → 이미 처리됨, SKIP
# 709/8597 → 이미 처리됨, SKIP
# 710/8597 → 이미 처리됨, SKIP
# 711/8597 → 이미 처리됨, SKIP
# 712/8597 → 이미 처리됨, SKIP
# 713/8597 → 이미 처리됨, SKIP
# 714/8597 → 이미 처리됨, SKIP
# 715/8597 → 이미 처리됨, SKIP
# 716/8597 → 이미 처리됨, SKIP
# 717/8597 → 이미 처리됨, SKIP
# 718/8597 → 이미 처리됨, SKIP
# 719/8597 → 이미 처리됨, SKIP
# 720/8597 → 이미 처리됨, SKIP
# 721/8597 → 이미 처리됨, SKIP
# 722/8597 → 이미 처리됨, SKIP
# 723/8597 → 이미 처리됨, SKIP
# 724/8597 → 이미 처리됨, SKIP
# 725/8597 → 이미 처리됨, SKIP
# 726/8597 → 이미 처리됨, SKIP
# 727/8597 → 이미 처리됨, SKIP
# 728/8597 → 이미 처리됨, SKIP
# 729/8597 → 이미 처리됨, SKIP
# 730/8597 → 이미 처리됨, SKIP
# 731/8597 → 이미 처리됨, SKIP
# 732/8597 → 이미 처리됨, SKIP
# 733/8597 → 이미 처리됨, SKIP
# 734/8597 → 이미 처리됨, SKIP
# 735/8597 → 이미 처리됨, SKIP
# 736/8597 → 이미 처리됨, SKIP
# 737/8597 → 이미 처리됨, SKIP
# 738/8597 → 이미 처리됨, SKIP
# 739/8597 → 이미 처리됨, SKIP
# 740/8597 → 이미 처리됨, SKIP
# 741/8597 → 이미 처리됨, SKIP
# 742/8597 → 이미 처리됨, SKIP
# 743/8597 → 이미 처리됨, SKIP
# 744/8597 → 이미 처리됨, SKIP
# 745/8597 → 이미 처리됨, SKIP
# 746/8597 → 이미 처리됨, SKIP
# 747/8597 → 이미 처리됨, SKIP
# 748/8597 → 이미 처리됨, SKIP
# 749/8597 → 이미 처리됨, SKIP
# 750/8597 → 이미 처리됨, SKIP
# 751/8597 → 이미 처리됨, SKIP
# 752/8597 → 이미 처리됨, SKIP
# 753/8597 → 이미 처리됨, SKIP
# 754/8597 → 이미 처리됨, SKIP
# 755/8597 → 이미 처리됨, SKIP
# 756/8597 → 이미 처리됨, SKIP
# 757/8597 → 이미 처리됨, SKIP
# 758/8597 → 이미 처리됨, SKIP
# 759/8597 → 이미 처리됨, SKIP
# 760/8597 → 이미 처리됨, SKIP
# 761/8597 → 이미 처리됨, SKIP
# 762/8597 → 이미 처리됨, SKIP
# 763/8597 → 이미 처리됨, SKIP
# 764/8597 → 이미 처리됨, SKIP
# 765/8597 → 이미 처리됨, SKIP
# 766/8597 → 이미 처리됨, SKIP
# 767/8597 → 이미 처리됨, SKIP
# 768/8597 → 이미 처리됨, SKIP
# 769/8597 → 이미 처리됨, SKIP
# 770/8597 → 이미 처리됨, SKIP
# 771/8597 → 이미 처리됨, SKIP
# 772/8597 → 이미 처리됨, SKIP
# 773/8597 → 이미 처리됨, SKIP
# 774/8597 → 이미 처리됨, SKIP
# 775/8597 → 이미 처리됨, SKIP
# 776/8597 → 이미 처리됨, SKIP
# 777/8597 → 이미 처리됨, SKIP
# 778/8597 → 이미 처리됨, SKIP
# 779/8597 → 이미 처리됨, SKIP
# 780/8597 → 이미 처리됨, SKIP
# 781/8597 → 이미 처리됨, SKIP
# 782/8597 → 이미 처리됨, SKIP
# 783/8597 → 이미 처리됨, SKIP
# 784/8597 → 이미 처리됨, SKIP
# 785/8597 → 이미 처리됨, SKIP
# 786/8597 → 이미 처리됨, SKIP
# 787/8597 → 이미 처리됨, SKIP
# 788/8597 → 이미 처리됨, SKIP
# 789/8597 → 이미 처리됨, SKIP
# 790/8597 → 이미 처리됨, SKIP
# 791/8597 → 이미 처리됨, SKIP
# 792/8597 → 이미 처리됨, SKIP
# 793/8597 → 이미 처리됨, SKIP
# 794/8597 → 이미 처리됨, SKIP
# 795/8597 → 이미 처리됨, SKIP
# 796/8597 → 이미 처리됨, SKIP
# 797/8597 → 이미 처리됨, SKIP
# 798/8597 → 이미 처리됨, SKIP
# 799/8597 → 이미 처리됨, SKIP
# 800/8597 → 이미 처리됨, SKIP
# 801/8597 → 이미 처리됨, SKIP
# 802/8597 → 이미 처리됨, SKIP
# 803/8597 → 이미 처리됨, SKIP
# 804/8597 → 이미 처리됨, SKIP
# 805/8597 → 이미 처리됨, SKIP
# 806/8597 → 이미 처리됨, SKIP
# 807/8597 → 이미 처리됨, SKIP
# 808/8597 → 이미 처리됨, SKIP
# 809/8597 → 이미 처리됨, SKIP
# 810/8597 → 이미 처리됨, SKIP
# 811/8597 → 이미 처리됨, SKIP
# 812/8597 → 이미 처리됨, SKIP
# 813/8597 → 이미 처리됨, SKIP
# 814/8597 → 이미 처리됨, SKIP
# 815/8597 → 이미 처리됨, SKIP
# 816/8597 → 이미 처리됨, SKIP
# 817/8597 → 이미 처리됨, SKIP
# 818/8597 → 이미 처리됨, SKIP
# 819/8597 → 이미 처리됨, SKIP
# 820/8597 → 이미 처리됨, SKIP
# 821/8597 → 이미 처리됨, SKIP
# 822/8597 → 이미 처리됨, SKIP
# 823/8597 → 이미 처리됨, SKIP
# 824/8597 → 이미 처리됨, SKIP
# 825/8597 → 이미 처리됨, SKIP
# 826/8597 → 이미 처리됨, SKIP
# 827/8597 → 이미 처리됨, SKIP
# 828/8597 → 이미 처리됨, SKIP
# 829/8597 → 이미 처리됨, SKIP
# 830/8597 → 이미 처리됨, SKIP
# 831/8597 → 이미 처리됨, SKIP
#
# ▶ 832/8597 — 주소 검색: 서울특별시 도봉구 쌍문동 69-1
#    ❗ 1차 실패 → 재검색: 서울특별시 도봉구 쌍문동 금호2
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 833/8597 → 이미 처리됨, SKIP
# 834/8597 → 이미 처리됨, SKIP
# 835/8597 → 이미 처리됨, SKIP
# 836/8597 → 이미 처리됨, SKIP
# 837/8597 → 이미 처리됨, SKIP
# 838/8597 → 이미 처리됨, SKIP
# 839/8597 → 이미 처리됨, SKIP
# 840/8597 → 이미 처리됨, SKIP
# 841/8597 → 이미 처리됨, SKIP
# 842/8597 → 이미 처리됨, SKIP
# 843/8597 → 이미 처리됨, SKIP
# 844/8597 → 이미 처리됨, SKIP
# 845/8597 → 이미 처리됨, SKIP
# 846/8597 → 이미 처리됨, SKIP
# 847/8597 → 이미 처리됨, SKIP
# 848/8597 → 이미 처리됨, SKIP
# 849/8597 → 이미 처리됨, SKIP
# 850/8597 → 이미 처리됨, SKIP
# 851/8597 → 이미 처리됨, SKIP
# 852/8597 → 이미 처리됨, SKIP
# 853/8597 → 이미 처리됨, SKIP
# 854/8597 → 이미 처리됨, SKIP
# 855/8597 → 이미 처리됨, SKIP
# 856/8597 → 이미 처리됨, SKIP
# 857/8597 → 이미 처리됨, SKIP
# 858/8597 → 이미 처리됨, SKIP
# 859/8597 → 이미 처리됨, SKIP
# 860/8597 → 이미 처리됨, SKIP
# 861/8597 → 이미 처리됨, SKIP
# 862/8597 → 이미 처리됨, SKIP
# 863/8597 → 이미 처리됨, SKIP
# 864/8597 → 이미 처리됨, SKIP
# 865/8597 → 이미 처리됨, SKIP
# 866/8597 → 이미 처리됨, SKIP
# 867/8597 → 이미 처리됨, SKIP
# 868/8597 → 이미 처리됨, SKIP
# 869/8597 → 이미 처리됨, SKIP
# 870/8597 → 이미 처리됨, SKIP
# 871/8597 → 이미 처리됨, SKIP
# 872/8597 → 이미 처리됨, SKIP
# 873/8597 → 이미 처리됨, SKIP
# 874/8597 → 이미 처리됨, SKIP
# 875/8597 → 이미 처리됨, SKIP
# 876/8597 → 이미 처리됨, SKIP
# 877/8597 → 이미 처리됨, SKIP
# 878/8597 → 이미 처리됨, SKIP
# 879/8597 → 이미 처리됨, SKIP
# 880/8597 → 이미 처리됨, SKIP
# 881/8597 → 이미 처리됨, SKIP
# 882/8597 → 이미 처리됨, SKIP
# 883/8597 → 이미 처리됨, SKIP
# 884/8597 → 이미 처리됨, SKIP
# 885/8597 → 이미 처리됨, SKIP
# 886/8597 → 이미 처리됨, SKIP
# 887/8597 → 이미 처리됨, SKIP
# 888/8597 → 이미 처리됨, SKIP
# 889/8597 → 이미 처리됨, SKIP
# 890/8597 → 이미 처리됨, SKIP
# 891/8597 → 이미 처리됨, SKIP
# 892/8597 → 이미 처리됨, SKIP
# 893/8597 → 이미 처리됨, SKIP
# 894/8597 → 이미 처리됨, SKIP
# 895/8597 → 이미 처리됨, SKIP
# 896/8597 → 이미 처리됨, SKIP
# 897/8597 → 이미 처리됨, SKIP
# 898/8597 → 이미 처리됨, SKIP
# 899/8597 → 이미 처리됨, SKIP
# 900/8597 → 이미 처리됨, SKIP
# 901/8597 → 이미 처리됨, SKIP
# 902/8597 → 이미 처리됨, SKIP
# 903/8597 → 이미 처리됨, SKIP
# 904/8597 → 이미 처리됨, SKIP
# 905/8597 → 이미 처리됨, SKIP
# 906/8597 → 이미 처리됨, SKIP
# 907/8597 → 이미 처리됨, SKIP
# 908/8597 → 이미 처리됨, SKIP
# 909/8597 → 이미 처리됨, SKIP
# 910/8597 → 이미 처리됨, SKIP
# 911/8597 → 이미 처리됨, SKIP
# 912/8597 → 이미 처리됨, SKIP
# 913/8597 → 이미 처리됨, SKIP
# 914/8597 → 이미 처리됨, SKIP
# 915/8597 → 이미 처리됨, SKIP
# 916/8597 → 이미 처리됨, SKIP
# 917/8597 → 이미 처리됨, SKIP
# 918/8597 → 이미 처리됨, SKIP
# 919/8597 → 이미 처리됨, SKIP
# 920/8597 → 이미 처리됨, SKIP
# 921/8597 → 이미 처리됨, SKIP
# 922/8597 → 이미 처리됨, SKIP
# 923/8597 → 이미 처리됨, SKIP
# 924/8597 → 이미 처리됨, SKIP
# 925/8597 → 이미 처리됨, SKIP
# 926/8597 → 이미 처리됨, SKIP
# 927/8597 → 이미 처리됨, SKIP
# 928/8597 → 이미 처리됨, SKIP
# 929/8597 → 이미 처리됨, SKIP
# 930/8597 → 이미 처리됨, SKIP
# 931/8597 → 이미 처리됨, SKIP
# 932/8597 → 이미 처리됨, SKIP
# 933/8597 → 이미 처리됨, SKIP
# 934/8597 → 이미 처리됨, SKIP
# 935/8597 → 이미 처리됨, SKIP
# 936/8597 → 이미 처리됨, SKIP
# 937/8597 → 이미 처리됨, SKIP
# 938/8597 → 이미 처리됨, SKIP
# 939/8597 → 이미 처리됨, SKIP
# 940/8597 → 이미 처리됨, SKIP
# 941/8597 → 이미 처리됨, SKIP
# 942/8597 → 이미 처리됨, SKIP
# 943/8597 → 이미 처리됨, SKIP
# 944/8597 → 이미 처리됨, SKIP
# 945/8597 → 이미 처리됨, SKIP
# 946/8597 → 이미 처리됨, SKIP
# 947/8597 → 이미 처리됨, SKIP
# 948/8597 → 이미 처리됨, SKIP
# 949/8597 → 이미 처리됨, SKIP
# 950/8597 → 이미 처리됨, SKIP
# 951/8597 → 이미 처리됨, SKIP
# 952/8597 → 이미 처리됨, SKIP
# 953/8597 → 이미 처리됨, SKIP
# 954/8597 → 이미 처리됨, SKIP
# 955/8597 → 이미 처리됨, SKIP
# 956/8597 → 이미 처리됨, SKIP
# 957/8597 → 이미 처리됨, SKIP
# 958/8597 → 이미 처리됨, SKIP
# 959/8597 → 이미 처리됨, SKIP
# 960/8597 → 이미 처리됨, SKIP
# 961/8597 → 이미 처리됨, SKIP
# 962/8597 → 이미 처리됨, SKIP
# 963/8597 → 이미 처리됨, SKIP
# 964/8597 → 이미 처리됨, SKIP
# 965/8597 → 이미 처리됨, SKIP
# 966/8597 → 이미 처리됨, SKIP
# 967/8597 → 이미 처리됨, SKIP
# 968/8597 → 이미 처리됨, SKIP
# 969/8597 → 이미 처리됨, SKIP
# 970/8597 → 이미 처리됨, SKIP
# 971/8597 → 이미 처리됨, SKIP
# 972/8597 → 이미 처리됨, SKIP
# 973/8597 → 이미 처리됨, SKIP
# 974/8597 → 이미 처리됨, SKIP
# 975/8597 → 이미 처리됨, SKIP
# 976/8597 → 이미 처리됨, SKIP
# 977/8597 → 이미 처리됨, SKIP
# 978/8597 → 이미 처리됨, SKIP
# 979/8597 → 이미 처리됨, SKIP
# 980/8597 → 이미 처리됨, SKIP
# 981/8597 → 이미 처리됨, SKIP
# 982/8597 → 이미 처리됨, SKIP
# 983/8597 → 이미 처리됨, SKIP
# 984/8597 → 이미 처리됨, SKIP
# 985/8597 → 이미 처리됨, SKIP
# 986/8597 → 이미 처리됨, SKIP
# 987/8597 → 이미 처리됨, SKIP
# 988/8597 → 이미 처리됨, SKIP
# 989/8597 → 이미 처리됨, SKIP
# 990/8597 → 이미 처리됨, SKIP
# 991/8597 → 이미 처리됨, SKIP
# 992/8597 → 이미 처리됨, SKIP
# 993/8597 → 이미 처리됨, SKIP
# 994/8597 → 이미 처리됨, SKIP
# 995/8597 → 이미 처리됨, SKIP
# 996/8597 → 이미 처리됨, SKIP
# 997/8597 → 이미 처리됨, SKIP
# 998/8597 → 이미 처리됨, SKIP
# 999/8597 → 이미 처리됨, SKIP
# 1000/8597 → 이미 처리됨, SKIP
# 1001/8597 → 이미 처리됨, SKIP
# 1002/8597 → 이미 처리됨, SKIP
# 1003/8597 → 이미 처리됨, SKIP
# 1004/8597 → 이미 처리됨, SKIP
# 1005/8597 → 이미 처리됨, SKIP
# 1006/8597 → 이미 처리됨, SKIP
# 1007/8597 → 이미 처리됨, SKIP
# 1008/8597 → 이미 처리됨, SKIP
# 1009/8597 → 이미 처리됨, SKIP
# 1010/8597 → 이미 처리됨, SKIP
# 1011/8597 → 이미 처리됨, SKIP
# 1012/8597 → 이미 처리됨, SKIP
# 1013/8597 → 이미 처리됨, SKIP
# 1014/8597 → 이미 처리됨, SKIP
# 1015/8597 → 이미 처리됨, SKIP
# 1016/8597 → 이미 처리됨, SKIP
# 1017/8597 → 이미 처리됨, SKIP
# 1018/8597 → 이미 처리됨, SKIP
# 1019/8597 → 이미 처리됨, SKIP
# 1020/8597 → 이미 처리됨, SKIP
# 1021/8597 → 이미 처리됨, SKIP
# 1022/8597 → 이미 처리됨, SKIP
# 1023/8597 → 이미 처리됨, SKIP
# 1024/8597 → 이미 처리됨, SKIP
# 1025/8597 → 이미 처리됨, SKIP
# 1026/8597 → 이미 처리됨, SKIP
# 1027/8597 → 이미 처리됨, SKIP
# 1028/8597 → 이미 처리됨, SKIP
# 1029/8597 → 이미 처리됨, SKIP
# 1030/8597 → 이미 처리됨, SKIP
# 1031/8597 → 이미 처리됨, SKIP
# 1032/8597 → 이미 처리됨, SKIP
# 1033/8597 → 이미 처리됨, SKIP
# 1034/8597 → 이미 처리됨, SKIP
# 1035/8597 → 이미 처리됨, SKIP
# 1036/8597 → 이미 처리됨, SKIP
# 1037/8597 → 이미 처리됨, SKIP
#
# ▶ 1038/8597 — 주소 검색: 서울특별시 노원구 상계동 6013-15
#    ❗ 1차 실패 → 재검색: 서울특별시 노원구 상계동 센트럴
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 1039/8597 → 이미 처리됨, SKIP
# 1040/8597 → 이미 처리됨, SKIP
#
# ▶ 1041/8597 — 주소 검색: 서울특별시 강서구 방화동 182-44
#    ❗ 1차 실패 → 재검색: 서울특별시 강서구 방화동 양진마니아
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 1042/8597 → 이미 처리됨, SKIP
# 1043/8597 → 이미 처리됨, SKIP
# 1044/8597 → 이미 처리됨, SKIP
# 1045/8597 → 이미 처리됨, SKIP
# 1046/8597 → 이미 처리됨, SKIP
# 1047/8597 → 이미 처리됨, SKIP
# 1048/8597 → 이미 처리됨, SKIP
# 1049/8597 → 이미 처리됨, SKIP
# 1050/8597 → 이미 처리됨, SKIP
# 1051/8597 → 이미 처리됨, SKIP
# 1052/8597 → 이미 처리됨, SKIP
# 1053/8597 → 이미 처리됨, SKIP
# 1054/8597 → 이미 처리됨, SKIP
# 1055/8597 → 이미 처리됨, SKIP
# 1056/8597 → 이미 처리됨, SKIP
# 1057/8597 → 이미 처리됨, SKIP
# 1058/8597 → 이미 처리됨, SKIP
#
# ▶ 1059/8597 — 주소 검색: 서울특별시 강서구 방화동 863
#    ❗ 1차 실패 → 재검색: 서울특별시 강서구 방화동 마곡현대아파트
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 1060/8597 → 이미 처리됨, SKIP
# 1061/8597 → 이미 처리됨, SKIP
# 1062/8597 → 이미 처리됨, SKIP
# 1063/8597 → 이미 처리됨, SKIP
# 1064/8597 → 이미 처리됨, SKIP
# 1065/8597 → 이미 처리됨, SKIP
# 1066/8597 → 이미 처리됨, SKIP
# 1067/8597 → 이미 처리됨, SKIP
# 1068/8597 → 이미 처리됨, SKIP
# 1069/8597 → 이미 처리됨, SKIP
# 1070/8597 → 이미 처리됨, SKIP
# 1071/8597 → 이미 처리됨, SKIP
# 1072/8597 → 이미 처리됨, SKIP
# 1073/8597 → 이미 처리됨, SKIP
# 1074/8597 → 이미 처리됨, SKIP
# 1075/8597 → 이미 처리됨, SKIP
# 1076/8597 → 이미 처리됨, SKIP
# 1077/8597 → 이미 처리됨, SKIP
# 1078/8597 → 이미 처리됨, SKIP
# 1079/8597 → 이미 처리됨, SKIP
# 1080/8597 → 이미 처리됨, SKIP
# 1081/8597 → 이미 처리됨, SKIP
# 1082/8597 → 이미 처리됨, SKIP
# 1083/8597 → 이미 처리됨, SKIP
# 1084/8597 → 이미 처리됨, SKIP
# 1085/8597 → 이미 처리됨, SKIP
# 1086/8597 → 이미 처리됨, SKIP
# 1087/8597 → 이미 처리됨, SKIP
# 1088/8597 → 이미 처리됨, SKIP
# 1089/8597 → 이미 처리됨, SKIP
# 1090/8597 → 이미 처리됨, SKIP
# 1091/8597 → 이미 처리됨, SKIP
# 1092/8597 → 이미 처리됨, SKIP
# 1093/8597 → 이미 처리됨, SKIP
# 1094/8597 → 이미 처리됨, SKIP
# 1095/8597 → 이미 처리됨, SKIP
# 1096/8597 → 이미 처리됨, SKIP
# 1097/8597 → 이미 처리됨, SKIP
# 1098/8597 → 이미 처리됨, SKIP
# 1099/8597 → 이미 처리됨, SKIP
# 1100/8597 → 이미 처리됨, SKIP
# 1101/8597 → 이미 처리됨, SKIP
# 1102/8597 → 이미 처리됨, SKIP
# 1103/8597 → 이미 처리됨, SKIP
# 1104/8597 → 이미 처리됨, SKIP
# 1105/8597 → 이미 처리됨, SKIP
# 1106/8597 → 이미 처리됨, SKIP
# 1107/8597 → 이미 처리됨, SKIP
# 1108/8597 → 이미 처리됨, SKIP
# 1109/8597 → 이미 처리됨, SKIP
# 1110/8597 → 이미 처리됨, SKIP
# 1111/8597 → 이미 처리됨, SKIP
# 1112/8597 → 이미 처리됨, SKIP
# 1113/8597 → 이미 처리됨, SKIP
# 1114/8597 → 이미 처리됨, SKIP
# 1115/8597 → 이미 처리됨, SKIP
# 1116/8597 → 이미 처리됨, SKIP
# 1117/8597 → 이미 처리됨, SKIP
# 1118/8597 → 이미 처리됨, SKIP
# 1119/8597 → 이미 처리됨, SKIP
# 1120/8597 → 이미 처리됨, SKIP
# 1121/8597 → 이미 처리됨, SKIP
# 1122/8597 → 이미 처리됨, SKIP
# 1123/8597 → 이미 처리됨, SKIP
# 1124/8597 → 이미 처리됨, SKIP
# 1125/8597 → 이미 처리됨, SKIP
# 1126/8597 → 이미 처리됨, SKIP
# 1127/8597 → 이미 처리됨, SKIP
# 1128/8597 → 이미 처리됨, SKIP
# 1129/8597 → 이미 처리됨, SKIP
# 1130/8597 → 이미 처리됨, SKIP
# 1131/8597 → 이미 처리됨, SKIP
# 1132/8597 → 이미 처리됨, SKIP
# 1133/8597 → 이미 처리됨, SKIP
# 1134/8597 → 이미 처리됨, SKIP
# 1135/8597 → 이미 처리됨, SKIP
# 1136/8597 → 이미 처리됨, SKIP
# 1137/8597 → 이미 처리됨, SKIP
# 1138/8597 → 이미 처리됨, SKIP
# 1139/8597 → 이미 처리됨, SKIP
# 1140/8597 → 이미 처리됨, SKIP
# 1141/8597 → 이미 처리됨, SKIP
# 1142/8597 → 이미 처리됨, SKIP
# 1143/8597 → 이미 처리됨, SKIP
# 1144/8597 → 이미 처리됨, SKIP
# 1145/8597 → 이미 처리됨, SKIP
# 1146/8597 → 이미 처리됨, SKIP
# 1147/8597 → 이미 처리됨, SKIP
# 1148/8597 → 이미 처리됨, SKIP
# 1149/8597 → 이미 처리됨, SKIP
# 1150/8597 → 이미 처리됨, SKIP
# 1151/8597 → 이미 처리됨, SKIP
# 1152/8597 → 이미 처리됨, SKIP
# 1153/8597 → 이미 처리됨, SKIP
# 1154/8597 → 이미 처리됨, SKIP
# 1155/8597 → 이미 처리됨, SKIP
# 1156/8597 → 이미 처리됨, SKIP
# 1157/8597 → 이미 처리됨, SKIP
# 1158/8597 → 이미 처리됨, SKIP
# 1159/8597 → 이미 처리됨, SKIP
# 1160/8597 → 이미 처리됨, SKIP
# 1161/8597 → 이미 처리됨, SKIP
# 1162/8597 → 이미 처리됨, SKIP
# 1163/8597 → 이미 처리됨, SKIP
# 1164/8597 → 이미 처리됨, SKIP
# 1165/8597 → 이미 처리됨, SKIP
# 1166/8597 → 이미 처리됨, SKIP
# 1167/8597 → 이미 처리됨, SKIP
# 1168/8597 → 이미 처리됨, SKIP
# 1169/8597 → 이미 처리됨, SKIP
# 1170/8597 → 이미 처리됨, SKIP
# 1171/8597 → 이미 처리됨, SKIP
# 1172/8597 → 이미 처리됨, SKIP
# 1173/8597 → 이미 처리됨, SKIP
# 1174/8597 → 이미 처리됨, SKIP
# 1175/8597 → 이미 처리됨, SKIP
# 1176/8597 → 이미 처리됨, SKIP
# 1177/8597 → 이미 처리됨, SKIP
# 1178/8597 → 이미 처리됨, SKIP
# 1179/8597 → 이미 처리됨, SKIP
# 1180/8597 → 이미 처리됨, SKIP
# 1181/8597 → 이미 처리됨, SKIP
# 1182/8597 → 이미 처리됨, SKIP
# 1183/8597 → 이미 처리됨, SKIP
# 1184/8597 → 이미 처리됨, SKIP
# 1185/8597 → 이미 처리됨, SKIP
# 1186/8597 → 이미 처리됨, SKIP
# 1187/8597 → 이미 처리됨, SKIP
# 1188/8597 → 이미 처리됨, SKIP
# 1189/8597 → 이미 처리됨, SKIP
# 1190/8597 → 이미 처리됨, SKIP
# 1191/8597 → 이미 처리됨, SKIP
# 1192/8597 → 이미 처리됨, SKIP
# 1193/8597 → 이미 처리됨, SKIP
# 1194/8597 → 이미 처리됨, SKIP
# 1195/8597 → 이미 처리됨, SKIP
# 1196/8597 → 이미 처리됨, SKIP
# 1197/8597 → 이미 처리됨, SKIP
# 1198/8597 → 이미 처리됨, SKIP
# 1199/8597 → 이미 처리됨, SKIP
# 1200/8597 → 이미 처리됨, SKIP
# 1201/8597 → 이미 처리됨, SKIP
# 1202/8597 → 이미 처리됨, SKIP
# 1203/8597 → 이미 처리됨, SKIP
# 1204/8597 → 이미 처리됨, SKIP
# 1205/8597 → 이미 처리됨, SKIP
# 1206/8597 → 이미 처리됨, SKIP
# 1207/8597 → 이미 처리됨, SKIP
# 1208/8597 → 이미 처리됨, SKIP
# 1209/8597 → 이미 처리됨, SKIP
# 1210/8597 → 이미 처리됨, SKIP
# 1211/8597 → 이미 처리됨, SKIP
# 1212/8597 → 이미 처리됨, SKIP
# 1213/8597 → 이미 처리됨, SKIP
# 1214/8597 → 이미 처리됨, SKIP
# 1215/8597 → 이미 처리됨, SKIP
# 1216/8597 → 이미 처리됨, SKIP
# 1217/8597 → 이미 처리됨, SKIP
# 1218/8597 → 이미 처리됨, SKIP
# 1219/8597 → 이미 처리됨, SKIP
# 1220/8597 → 이미 처리됨, SKIP
# 1221/8597 → 이미 처리됨, SKIP
# 1222/8597 → 이미 처리됨, SKIP
# 1223/8597 → 이미 처리됨, SKIP
# 1224/8597 → 이미 처리됨, SKIP
# 1225/8597 → 이미 처리됨, SKIP
# 1226/8597 → 이미 처리됨, SKIP
# 1227/8597 → 이미 처리됨, SKIP
# 1228/8597 → 이미 처리됨, SKIP
# 1229/8597 → 이미 처리됨, SKIP
# 1230/8597 → 이미 처리됨, SKIP
# 1231/8597 → 이미 처리됨, SKIP
# 1232/8597 → 이미 처리됨, SKIP
# 1233/8597 → 이미 처리됨, SKIP
# 1234/8597 → 이미 처리됨, SKIP
# 1235/8597 → 이미 처리됨, SKIP
# 1236/8597 → 이미 처리됨, SKIP
# 1237/8597 → 이미 처리됨, SKIP
# 1238/8597 → 이미 처리됨, SKIP
# 1239/8597 → 이미 처리됨, SKIP
# 1240/8597 → 이미 처리됨, SKIP
# 1241/8597 → 이미 처리됨, SKIP
# 1242/8597 → 이미 처리됨, SKIP
# 1243/8597 → 이미 처리됨, SKIP
# 1244/8597 → 이미 처리됨, SKIP
# 1245/8597 → 이미 처리됨, SKIP
# 1246/8597 → 이미 처리됨, SKIP
# 1247/8597 → 이미 처리됨, SKIP
# 1248/8597 → 이미 처리됨, SKIP
# 1249/8597 → 이미 처리됨, SKIP
# 1250/8597 → 이미 처리됨, SKIP
# 1251/8597 → 이미 처리됨, SKIP
# 1252/8597 → 이미 처리됨, SKIP
# 1253/8597 → 이미 처리됨, SKIP
# 1254/8597 → 이미 처리됨, SKIP
# 1255/8597 → 이미 처리됨, SKIP
# 1256/8597 → 이미 처리됨, SKIP
# 1257/8597 → 이미 처리됨, SKIP
# 1258/8597 → 이미 처리됨, SKIP
# 1259/8597 → 이미 처리됨, SKIP
# 1260/8597 → 이미 처리됨, SKIP
# 1261/8597 → 이미 처리됨, SKIP
# 1262/8597 → 이미 처리됨, SKIP
# 1263/8597 → 이미 처리됨, SKIP
# 1264/8597 → 이미 처리됨, SKIP
# 1265/8597 → 이미 처리됨, SKIP
# 1266/8597 → 이미 처리됨, SKIP
# 1267/8597 → 이미 처리됨, SKIP
# 1268/8597 → 이미 처리됨, SKIP
# 1269/8597 → 이미 처리됨, SKIP
# 1270/8597 → 이미 처리됨, SKIP
# 1271/8597 → 이미 처리됨, SKIP
# 1272/8597 → 이미 처리됨, SKIP
# 1273/8597 → 이미 처리됨, SKIP
# 1274/8597 → 이미 처리됨, SKIP
# 1275/8597 → 이미 처리됨, SKIP
# 1276/8597 → 이미 처리됨, SKIP
# 1277/8597 → 이미 처리됨, SKIP
# 1278/8597 → 이미 처리됨, SKIP
# 1279/8597 → 이미 처리됨, SKIP
# 1280/8597 → 이미 처리됨, SKIP
# 1281/8597 → 이미 처리됨, SKIP
# 1282/8597 → 이미 처리됨, SKIP
# 1283/8597 → 이미 처리됨, SKIP
# 1284/8597 → 이미 처리됨, SKIP
# 1285/8597 → 이미 처리됨, SKIP
# 1286/8597 → 이미 처리됨, SKIP
# 1287/8597 → 이미 처리됨, SKIP
# 1288/8597 → 이미 처리됨, SKIP
# 1289/8597 → 이미 처리됨, SKIP
# 1290/8597 → 이미 처리됨, SKIP
# 1291/8597 → 이미 처리됨, SKIP
# 1292/8597 → 이미 처리됨, SKIP
# 1293/8597 → 이미 처리됨, SKIP
# 1294/8597 → 이미 처리됨, SKIP
# 1295/8597 → 이미 처리됨, SKIP
# 1296/8597 → 이미 처리됨, SKIP
# 1297/8597 → 이미 처리됨, SKIP
# 1298/8597 → 이미 처리됨, SKIP
# 1299/8597 → 이미 처리됨, SKIP
# 1300/8597 → 이미 처리됨, SKIP
# 1301/8597 → 이미 처리됨, SKIP
# 1302/8597 → 이미 처리됨, SKIP
# 1303/8597 → 이미 처리됨, SKIP
# 1304/8597 → 이미 처리됨, SKIP
# 1305/8597 → 이미 처리됨, SKIP
# 1306/8597 → 이미 처리됨, SKIP
# 1307/8597 → 이미 처리됨, SKIP
# 1308/8597 → 이미 처리됨, SKIP
# 1309/8597 → 이미 처리됨, SKIP
# 1310/8597 → 이미 처리됨, SKIP
# 1311/8597 → 이미 처리됨, SKIP
# 1312/8597 → 이미 처리됨, SKIP
# 1313/8597 → 이미 처리됨, SKIP
# 1314/8597 → 이미 처리됨, SKIP
# 1315/8597 → 이미 처리됨, SKIP
# 1316/8597 → 이미 처리됨, SKIP
# 1317/8597 → 이미 처리됨, SKIP
# 1318/8597 → 이미 처리됨, SKIP
# 1319/8597 → 이미 처리됨, SKIP
# 1320/8597 → 이미 처리됨, SKIP
# 1321/8597 → 이미 처리됨, SKIP
# 1322/8597 → 이미 처리됨, SKIP
#
# ▶ 1323/8597 — 주소 검색: 서울특별시 노원구 공릉동 230
#    ❗ 1차 실패 → 재검색: 서울특별시 노원구 공릉동 현대아파트
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 1324/8597 → 이미 처리됨, SKIP
# 1325/8597 → 이미 처리됨, SKIP
# 1326/8597 → 이미 처리됨, SKIP
# 1327/8597 → 이미 처리됨, SKIP
# 1328/8597 → 이미 처리됨, SKIP
# 1329/8597 → 이미 처리됨, SKIP
# 1330/8597 → 이미 처리됨, SKIP
# 1331/8597 → 이미 처리됨, SKIP
# 1332/8597 → 이미 처리됨, SKIP
# 1333/8597 → 이미 처리됨, SKIP
# 1334/8597 → 이미 처리됨, SKIP
# 1335/8597 → 이미 처리됨, SKIP
# 1336/8597 → 이미 처리됨, SKIP
# 1337/8597 → 이미 처리됨, SKIP
# 1338/8597 → 이미 처리됨, SKIP
# 1339/8597 → 이미 처리됨, SKIP
# 1340/8597 → 이미 처리됨, SKIP
# 1341/8597 → 이미 처리됨, SKIP
# 1342/8597 → 이미 처리됨, SKIP
# 1343/8597 → 이미 처리됨, SKIP
# 1344/8597 → 이미 처리됨, SKIP
# 1345/8597 → 이미 처리됨, SKIP
# 1346/8597 → 이미 처리됨, SKIP
# 1347/8597 → 이미 처리됨, SKIP
# 1348/8597 → 이미 처리됨, SKIP
# 1349/8597 → 이미 처리됨, SKIP
# 1350/8597 → 이미 처리됨, SKIP
# 1351/8597 → 이미 처리됨, SKIP
# 1352/8597 → 이미 처리됨, SKIP
# 1353/8597 → 이미 처리됨, SKIP
# 1354/8597 → 이미 처리됨, SKIP
# 1355/8597 → 이미 처리됨, SKIP
# 1356/8597 → 이미 처리됨, SKIP
# 1357/8597 → 이미 처리됨, SKIP
# 1358/8597 → 이미 처리됨, SKIP
# 1359/8597 → 이미 처리됨, SKIP
# 1360/8597 → 이미 처리됨, SKIP
# 1361/8597 → 이미 처리됨, SKIP
# 1362/8597 → 이미 처리됨, SKIP
# 1363/8597 → 이미 처리됨, SKIP
# 1364/8597 → 이미 처리됨, SKIP
# 1365/8597 → 이미 처리됨, SKIP
# 1366/8597 → 이미 처리됨, SKIP
# 1367/8597 → 이미 처리됨, SKIP
# 1368/8597 → 이미 처리됨, SKIP
# 1369/8597 → 이미 처리됨, SKIP
# 1370/8597 → 이미 처리됨, SKIP
# 1371/8597 → 이미 처리됨, SKIP
# 1372/8597 → 이미 처리됨, SKIP
# 1373/8597 → 이미 처리됨, SKIP
# 1374/8597 → 이미 처리됨, SKIP
# 1375/8597 → 이미 처리됨, SKIP
# 1376/8597 → 이미 처리됨, SKIP
# 1377/8597 → 이미 처리됨, SKIP
# 1378/8597 → 이미 처리됨, SKIP
# 1379/8597 → 이미 처리됨, SKIP
# 1380/8597 → 이미 처리됨, SKIP
# 1381/8597 → 이미 처리됨, SKIP
# 1382/8597 → 이미 처리됨, SKIP
# 1383/8597 → 이미 처리됨, SKIP
# 1384/8597 → 이미 처리됨, SKIP
# 1385/8597 → 이미 처리됨, SKIP
# 1386/8597 → 이미 처리됨, SKIP
# 1387/8597 → 이미 처리됨, SKIP
# 1388/8597 → 이미 처리됨, SKIP
# 1389/8597 → 이미 처리됨, SKIP
# 1390/8597 → 이미 처리됨, SKIP
# 1391/8597 → 이미 처리됨, SKIP
# 1392/8597 → 이미 처리됨, SKIP
# 1393/8597 → 이미 처리됨, SKIP
# 1394/8597 → 이미 처리됨, SKIP
# 1395/8597 → 이미 처리됨, SKIP
# 1396/8597 → 이미 처리됨, SKIP
# 1397/8597 → 이미 처리됨, SKIP
# 1398/8597 → 이미 처리됨, SKIP
# 1399/8597 → 이미 처리됨, SKIP
# 1400/8597 → 이미 처리됨, SKIP
# 1401/8597 → 이미 처리됨, SKIP
# 1402/8597 → 이미 처리됨, SKIP
# 1403/8597 → 이미 처리됨, SKIP
# 1404/8597 → 이미 처리됨, SKIP
# 1405/8597 → 이미 처리됨, SKIP
# 1406/8597 → 이미 처리됨, SKIP
# 1407/8597 → 이미 처리됨, SKIP
# 1408/8597 → 이미 처리됨, SKIP
# 1409/8597 → 이미 처리됨, SKIP
# 1410/8597 → 이미 처리됨, SKIP
# 1411/8597 → 이미 처리됨, SKIP
# 1412/8597 → 이미 처리됨, SKIP
# 1413/8597 → 이미 처리됨, SKIP
# 1414/8597 → 이미 처리됨, SKIP
# 1415/8597 → 이미 처리됨, SKIP
# 1416/8597 → 이미 처리됨, SKIP
# 1417/8597 → 이미 처리됨, SKIP
# 1418/8597 → 이미 처리됨, SKIP
# 1419/8597 → 이미 처리됨, SKIP
# 1420/8597 → 이미 처리됨, SKIP
# 1421/8597 → 이미 처리됨, SKIP
# 1422/8597 → 이미 처리됨, SKIP
# 1423/8597 → 이미 처리됨, SKIP
# 1424/8597 → 이미 처리됨, SKIP
# 1425/8597 → 이미 처리됨, SKIP
# 1426/8597 → 이미 처리됨, SKIP
# 1427/8597 → 이미 처리됨, SKIP
# 1428/8597 → 이미 처리됨, SKIP
#
# ▶ 1429/8597 — 주소 검색: 서울특별시 서대문구 북아현동 149
#    ❗ 1차 실패 → 재검색: 서울특별시 서대문구 북아현동 e편한세상신촌3단지
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 1430/8597 → 이미 처리됨, SKIP
# 1431/8597 → 이미 처리됨, SKIP
# 1432/8597 → 이미 처리됨, SKIP
# 1433/8597 → 이미 처리됨, SKIP
# 1434/8597 → 이미 처리됨, SKIP
# 1435/8597 → 이미 처리됨, SKIP
#
# ▶ 1436/8597 — 주소 검색: 서울특별시 강남구 율현동 8
#    ❗ 1차 실패 → 재검색: 서울특별시 강남구 율현동 강남한신휴플러스8단지
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 1437/8597 → 이미 처리됨, SKIP
# 1438/8597 → 이미 처리됨, SKIP
# 1439/8597 → 이미 처리됨, SKIP
# 1440/8597 → 이미 처리됨, SKIP
# 1441/8597 → 이미 처리됨, SKIP
# 1442/8597 → 이미 처리됨, SKIP
# 1443/8597 → 이미 처리됨, SKIP
# 1444/8597 → 이미 처리됨, SKIP
# 1445/8597 → 이미 처리됨, SKIP
# 1446/8597 → 이미 처리됨, SKIP
# 1447/8597 → 이미 처리됨, SKIP
# 1448/8597 → 이미 처리됨, SKIP
# 1449/8597 → 이미 처리됨, SKIP
# 1450/8597 → 이미 처리됨, SKIP
# 1451/8597 → 이미 처리됨, SKIP
# 1452/8597 → 이미 처리됨, SKIP
# 1453/8597 → 이미 처리됨, SKIP
# 1454/8597 → 이미 처리됨, SKIP
# 1455/8597 → 이미 처리됨, SKIP
# 1456/8597 → 이미 처리됨, SKIP
# 1457/8597 → 이미 처리됨, SKIP
# 1458/8597 → 이미 처리됨, SKIP
# 1459/8597 → 이미 처리됨, SKIP
# 1460/8597 → 이미 처리됨, SKIP
# 1461/8597 → 이미 처리됨, SKIP
# 1462/8597 → 이미 처리됨, SKIP
# 1463/8597 → 이미 처리됨, SKIP
# 1464/8597 → 이미 처리됨, SKIP
# 1465/8597 → 이미 처리됨, SKIP
# 1466/8597 → 이미 처리됨, SKIP
# 1467/8597 → 이미 처리됨, SKIP
# 1468/8597 → 이미 처리됨, SKIP
# 1469/8597 → 이미 처리됨, SKIP
# 1470/8597 → 이미 처리됨, SKIP
# 1471/8597 → 이미 처리됨, SKIP
# 1472/8597 → 이미 처리됨, SKIP
# 1473/8597 → 이미 처리됨, SKIP
# 1474/8597 → 이미 처리됨, SKIP
# 1475/8597 → 이미 처리됨, SKIP
# 1476/8597 → 이미 처리됨, SKIP
# 1477/8597 → 이미 처리됨, SKIP
# 1478/8597 → 이미 처리됨, SKIP
# 1479/8597 → 이미 처리됨, SKIP
# 1480/8597 → 이미 처리됨, SKIP
# 1481/8597 → 이미 처리됨, SKIP
# 1482/8597 → 이미 처리됨, SKIP
# 1483/8597 → 이미 처리됨, SKIP
# 1484/8597 → 이미 처리됨, SKIP
# 1485/8597 → 이미 처리됨, SKIP
# 1486/8597 → 이미 처리됨, SKIP
# 1487/8597 → 이미 처리됨, SKIP
# 1488/8597 → 이미 처리됨, SKIP
# 1489/8597 → 이미 처리됨, SKIP
# 1490/8597 → 이미 처리됨, SKIP
# 1491/8597 → 이미 처리됨, SKIP
# 1492/8597 → 이미 처리됨, SKIP
# 1493/8597 → 이미 처리됨, SKIP
# 1494/8597 → 이미 처리됨, SKIP
# 1495/8597 → 이미 처리됨, SKIP
# 1496/8597 → 이미 처리됨, SKIP
# 1497/8597 → 이미 처리됨, SKIP
# 1498/8597 → 이미 처리됨, SKIP
# 1499/8597 → 이미 처리됨, SKIP
# 1500/8597 → 이미 처리됨, SKIP
# 1501/8597 → 이미 처리됨, SKIP
# 1502/8597 → 이미 처리됨, SKIP
# 1503/8597 → 이미 처리됨, SKIP
# 1504/8597 → 이미 처리됨, SKIP
# 1505/8597 → 이미 처리됨, SKIP
# 1506/8597 → 이미 처리됨, SKIP
# 1507/8597 → 이미 처리됨, SKIP
# 1508/8597 → 이미 처리됨, SKIP
# 1509/8597 → 이미 처리됨, SKIP
# 1510/8597 → 이미 처리됨, SKIP
# 1511/8597 → 이미 처리됨, SKIP
# 1512/8597 → 이미 처리됨, SKIP
# 1513/8597 → 이미 처리됨, SKIP
# 1514/8597 → 이미 처리됨, SKIP
# 1515/8597 → 이미 처리됨, SKIP
# 1516/8597 → 이미 처리됨, SKIP
# 1517/8597 → 이미 처리됨, SKIP
# 1518/8597 → 이미 처리됨, SKIP
# 1519/8597 → 이미 처리됨, SKIP
# 1520/8597 → 이미 처리됨, SKIP
# 1521/8597 → 이미 처리됨, SKIP
# 1522/8597 → 이미 처리됨, SKIP
# 1523/8597 → 이미 처리됨, SKIP
# 1524/8597 → 이미 처리됨, SKIP
# 1525/8597 → 이미 처리됨, SKIP
# 1526/8597 → 이미 처리됨, SKIP
# 1527/8597 → 이미 처리됨, SKIP
# 1528/8597 → 이미 처리됨, SKIP
# 1529/8597 → 이미 처리됨, SKIP
# 1530/8597 → 이미 처리됨, SKIP
# 1531/8597 → 이미 처리됨, SKIP
# 1532/8597 → 이미 처리됨, SKIP
# 1533/8597 → 이미 처리됨, SKIP
# 1534/8597 → 이미 처리됨, SKIP
# 1535/8597 → 이미 처리됨, SKIP
# 1536/8597 → 이미 처리됨, SKIP
# 1537/8597 → 이미 처리됨, SKIP
# 1538/8597 → 이미 처리됨, SKIP
# 1539/8597 → 이미 처리됨, SKIP
# 1540/8597 → 이미 처리됨, SKIP
# 1541/8597 → 이미 처리됨, SKIP
# 1542/8597 → 이미 처리됨, SKIP
# 1543/8597 → 이미 처리됨, SKIP
# 1544/8597 → 이미 처리됨, SKIP
# 1545/8597 → 이미 처리됨, SKIP
# 1546/8597 → 이미 처리됨, SKIP
# 1547/8597 → 이미 처리됨, SKIP
# 1548/8597 → 이미 처리됨, SKIP
# 1549/8597 → 이미 처리됨, SKIP
# 1550/8597 → 이미 처리됨, SKIP
# 1551/8597 → 이미 처리됨, SKIP
# 1552/8597 → 이미 처리됨, SKIP
# 1553/8597 → 이미 처리됨, SKIP
# 1554/8597 → 이미 처리됨, SKIP
#
# ▶ 1555/8597 — 주소 검색: 서울특별시 강서구 방화동 168-38
#    ❗ 1차 실패 → 재검색: 서울특별시 강서구 방화동 한림리첸빌101동
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 1556/8597 → 이미 처리됨, SKIP
# 1557/8597 → 이미 처리됨, SKIP
# 1558/8597 → 이미 처리됨, SKIP
# 1559/8597 → 이미 처리됨, SKIP
# 1560/8597 → 이미 처리됨, SKIP
# 1561/8597 → 이미 처리됨, SKIP
# 1562/8597 → 이미 처리됨, SKIP
# 1563/8597 → 이미 처리됨, SKIP
# 1564/8597 → 이미 처리됨, SKIP
# 1565/8597 → 이미 처리됨, SKIP
# 1566/8597 → 이미 처리됨, SKIP
# 1567/8597 → 이미 처리됨, SKIP
# 1568/8597 → 이미 처리됨, SKIP
# 1569/8597 → 이미 처리됨, SKIP
# 1570/8597 → 이미 처리됨, SKIP
# 1571/8597 → 이미 처리됨, SKIP
# 1572/8597 → 이미 처리됨, SKIP
# 1573/8597 → 이미 처리됨, SKIP
# 1574/8597 → 이미 처리됨, SKIP
# 1575/8597 → 이미 처리됨, SKIP
# 1576/8597 → 이미 처리됨, SKIP
# 1577/8597 → 이미 처리됨, SKIP
# 1578/8597 → 이미 처리됨, SKIP
# 1579/8597 → 이미 처리됨, SKIP
# 1580/8597 → 이미 처리됨, SKIP
# 1581/8597 → 이미 처리됨, SKIP
# 1582/8597 → 이미 처리됨, SKIP
# 1583/8597 → 이미 처리됨, SKIP
# 1584/8597 → 이미 처리됨, SKIP
# 1585/8597 → 이미 처리됨, SKIP
# 1586/8597 → 이미 처리됨, SKIP
# 1587/8597 → 이미 처리됨, SKIP
# 1588/8597 → 이미 처리됨, SKIP
# 1589/8597 → 이미 처리됨, SKIP
# 1590/8597 → 이미 처리됨, SKIP
# 1591/8597 → 이미 처리됨, SKIP
# 1592/8597 → 이미 처리됨, SKIP
# 1593/8597 → 이미 처리됨, SKIP
# 1594/8597 → 이미 처리됨, SKIP
# 1595/8597 → 이미 처리됨, SKIP
# 1596/8597 → 이미 처리됨, SKIP
# 1597/8597 → 이미 처리됨, SKIP
# 1598/8597 → 이미 처리됨, SKIP
# 1599/8597 → 이미 처리됨, SKIP
# 1600/8597 → 이미 처리됨, SKIP
# 1601/8597 → 이미 처리됨, SKIP
# 1602/8597 → 이미 처리됨, SKIP
# 1603/8597 → 이미 처리됨, SKIP
# 1604/8597 → 이미 처리됨, SKIP
# 1605/8597 → 이미 처리됨, SKIP
# 1606/8597 → 이미 처리됨, SKIP
# 1607/8597 → 이미 처리됨, SKIP
# 1608/8597 → 이미 처리됨, SKIP
# 1609/8597 → 이미 처리됨, SKIP
# 1610/8597 → 이미 처리됨, SKIP
# 1611/8597 → 이미 처리됨, SKIP
# 1612/8597 → 이미 처리됨, SKIP
# 1613/8597 → 이미 처리됨, SKIP
# 1614/8597 → 이미 처리됨, SKIP
# 1615/8597 → 이미 처리됨, SKIP
# 1616/8597 → 이미 처리됨, SKIP
# 1617/8597 → 이미 처리됨, SKIP
# 1618/8597 → 이미 처리됨, SKIP
# 1619/8597 → 이미 처리됨, SKIP
# 1620/8597 → 이미 처리됨, SKIP
# 1621/8597 → 이미 처리됨, SKIP
# 1622/8597 → 이미 처리됨, SKIP
# 1623/8597 → 이미 처리됨, SKIP
# 1624/8597 → 이미 처리됨, SKIP
# 1625/8597 → 이미 처리됨, SKIP
# 1626/8597 → 이미 처리됨, SKIP
# 1627/8597 → 이미 처리됨, SKIP
# 1628/8597 → 이미 처리됨, SKIP
# 1629/8597 → 이미 처리됨, SKIP
# 1630/8597 → 이미 처리됨, SKIP
# 1631/8597 → 이미 처리됨, SKIP
# 1632/8597 → 이미 처리됨, SKIP
# 1633/8597 → 이미 처리됨, SKIP
# 1634/8597 → 이미 처리됨, SKIP
# 1635/8597 → 이미 처리됨, SKIP
# 1636/8597 → 이미 처리됨, SKIP
# 1637/8597 → 이미 처리됨, SKIP
# 1638/8597 → 이미 처리됨, SKIP
# 1639/8597 → 이미 처리됨, SKIP
# 1640/8597 → 이미 처리됨, SKIP
# 1641/8597 → 이미 처리됨, SKIP
# 1642/8597 → 이미 처리됨, SKIP
# 1643/8597 → 이미 처리됨, SKIP
# 1644/8597 → 이미 처리됨, SKIP
# 1645/8597 → 이미 처리됨, SKIP
# 1646/8597 → 이미 처리됨, SKIP
# 1647/8597 → 이미 처리됨, SKIP
# 1648/8597 → 이미 처리됨, SKIP
# 1649/8597 → 이미 처리됨, SKIP
# 1650/8597 → 이미 처리됨, SKIP
# 1651/8597 → 이미 처리됨, SKIP
# 1652/8597 → 이미 처리됨, SKIP
# 1653/8597 → 이미 처리됨, SKIP
# 1654/8597 → 이미 처리됨, SKIP
# 1655/8597 → 이미 처리됨, SKIP
# 1656/8597 → 이미 처리됨, SKIP
# 1657/8597 → 이미 처리됨, SKIP
# 1658/8597 → 이미 처리됨, SKIP
# 1659/8597 → 이미 처리됨, SKIP
# 1660/8597 → 이미 처리됨, SKIP
# 1661/8597 → 이미 처리됨, SKIP
# 1662/8597 → 이미 처리됨, SKIP
# 1663/8597 → 이미 처리됨, SKIP
# 1664/8597 → 이미 처리됨, SKIP
# 1665/8597 → 이미 처리됨, SKIP
# 1666/8597 → 이미 처리됨, SKIP
# 1667/8597 → 이미 처리됨, SKIP
# 1668/8597 → 이미 처리됨, SKIP
# 1669/8597 → 이미 처리됨, SKIP
# 1670/8597 → 이미 처리됨, SKIP
# 1671/8597 → 이미 처리됨, SKIP
# 1672/8597 → 이미 처리됨, SKIP
# 1673/8597 → 이미 처리됨, SKIP
# 1674/8597 → 이미 처리됨, SKIP
# 1675/8597 → 이미 처리됨, SKIP
# 1676/8597 → 이미 처리됨, SKIP
# 1677/8597 → 이미 처리됨, SKIP
# 1678/8597 → 이미 처리됨, SKIP
# 1679/8597 → 이미 처리됨, SKIP
# 1680/8597 → 이미 처리됨, SKIP
# 1681/8597 → 이미 처리됨, SKIP
# 1682/8597 → 이미 처리됨, SKIP
# 1683/8597 → 이미 처리됨, SKIP
# 1684/8597 → 이미 처리됨, SKIP
# 1685/8597 → 이미 처리됨, SKIP
# 1686/8597 → 이미 처리됨, SKIP
# 1687/8597 → 이미 처리됨, SKIP
# 1688/8597 → 이미 처리됨, SKIP
# 1689/8597 → 이미 처리됨, SKIP
# 1690/8597 → 이미 처리됨, SKIP
# 1691/8597 → 이미 처리됨, SKIP
# 1692/8597 → 이미 처리됨, SKIP
# 1693/8597 → 이미 처리됨, SKIP
# 1694/8597 → 이미 처리됨, SKIP
# 1695/8597 → 이미 처리됨, SKIP
# 1696/8597 → 이미 처리됨, SKIP
# 1697/8597 → 이미 처리됨, SKIP
# 1698/8597 → 이미 처리됨, SKIP
# 1699/8597 → 이미 처리됨, SKIP
# 1700/8597 → 이미 처리됨, SKIP
# 1701/8597 → 이미 처리됨, SKIP
# 1702/8597 → 이미 처리됨, SKIP
# 1703/8597 → 이미 처리됨, SKIP
# 1704/8597 → 이미 처리됨, SKIP
# 1705/8597 → 이미 처리됨, SKIP
# 1706/8597 → 이미 처리됨, SKIP
# 1707/8597 → 이미 처리됨, SKIP
# 1708/8597 → 이미 처리됨, SKIP
# 1709/8597 → 이미 처리됨, SKIP
# 1710/8597 → 이미 처리됨, SKIP
# 1711/8597 → 이미 처리됨, SKIP
# 1712/8597 → 이미 처리됨, SKIP
# 1713/8597 → 이미 처리됨, SKIP
# 1714/8597 → 이미 처리됨, SKIP
# 1715/8597 → 이미 처리됨, SKIP
# 1716/8597 → 이미 처리됨, SKIP
# 1717/8597 → 이미 처리됨, SKIP
# 1718/8597 → 이미 처리됨, SKIP
# 1719/8597 → 이미 처리됨, SKIP
# 1720/8597 → 이미 처리됨, SKIP
# 1721/8597 → 이미 처리됨, SKIP
# 1722/8597 → 이미 처리됨, SKIP
# 1723/8597 → 이미 처리됨, SKIP
# 1724/8597 → 이미 처리됨, SKIP
# 1725/8597 → 이미 처리됨, SKIP
# 1726/8597 → 이미 처리됨, SKIP
# 1727/8597 → 이미 처리됨, SKIP
# 1728/8597 → 이미 처리됨, SKIP
# 1729/8597 → 이미 처리됨, SKIP
# 1730/8597 → 이미 처리됨, SKIP
# 1731/8597 → 이미 처리됨, SKIP
# 1732/8597 → 이미 처리됨, SKIP
# 1733/8597 → 이미 처리됨, SKIP
# 1734/8597 → 이미 처리됨, SKIP
# 1735/8597 → 이미 처리됨, SKIP
# 1736/8597 → 이미 처리됨, SKIP
# 1737/8597 → 이미 처리됨, SKIP
# 1738/8597 → 이미 처리됨, SKIP
# 1739/8597 → 이미 처리됨, SKIP
# 1740/8597 → 이미 처리됨, SKIP
# 1741/8597 → 이미 처리됨, SKIP
# 1742/8597 → 이미 처리됨, SKIP
# 1743/8597 → 이미 처리됨, SKIP
# 1744/8597 → 이미 처리됨, SKIP
# 1745/8597 → 이미 처리됨, SKIP
# 1746/8597 → 이미 처리됨, SKIP
# 1747/8597 → 이미 처리됨, SKIP
# 1748/8597 → 이미 처리됨, SKIP
# 1749/8597 → 이미 처리됨, SKIP
# 1750/8597 → 이미 처리됨, SKIP
# 1751/8597 → 이미 처리됨, SKIP
# 1752/8597 → 이미 처리됨, SKIP
# 1753/8597 → 이미 처리됨, SKIP
# 1754/8597 → 이미 처리됨, SKIP
# 1755/8597 → 이미 처리됨, SKIP
# 1756/8597 → 이미 처리됨, SKIP
# 1757/8597 → 이미 처리됨, SKIP
# 1758/8597 → 이미 처리됨, SKIP
# 1759/8597 → 이미 처리됨, SKIP
# 1760/8597 → 이미 처리됨, SKIP
# 1761/8597 → 이미 처리됨, SKIP
# 1762/8597 → 이미 처리됨, SKIP
# 1763/8597 → 이미 처리됨, SKIP
# 1764/8597 → 이미 처리됨, SKIP
# 1765/8597 → 이미 처리됨, SKIP
# 1766/8597 → 이미 처리됨, SKIP
# 1767/8597 → 이미 처리됨, SKIP
# 1768/8597 → 이미 처리됨, SKIP
# 1769/8597 → 이미 처리됨, SKIP
# 1770/8597 → 이미 처리됨, SKIP
# 1771/8597 → 이미 처리됨, SKIP
# 1772/8597 → 이미 처리됨, SKIP
# 1773/8597 → 이미 처리됨, SKIP
# 1774/8597 → 이미 처리됨, SKIP
# 1775/8597 → 이미 처리됨, SKIP
# 1776/8597 → 이미 처리됨, SKIP
# 1777/8597 → 이미 처리됨, SKIP
# 1778/8597 → 이미 처리됨, SKIP
# 1779/8597 → 이미 처리됨, SKIP
# 1780/8597 → 이미 처리됨, SKIP
# 1781/8597 → 이미 처리됨, SKIP
# 1782/8597 → 이미 처리됨, SKIP
# 1783/8597 → 이미 처리됨, SKIP
# 1784/8597 → 이미 처리됨, SKIP
# 1785/8597 → 이미 처리됨, SKIP
# 1786/8597 → 이미 처리됨, SKIP
# 1787/8597 → 이미 처리됨, SKIP
# 1788/8597 → 이미 처리됨, SKIP
# 1789/8597 → 이미 처리됨, SKIP
# 1790/8597 → 이미 처리됨, SKIP
# 1791/8597 → 이미 처리됨, SKIP
# 1792/8597 → 이미 처리됨, SKIP
# 1793/8597 → 이미 처리됨, SKIP
# 1794/8597 → 이미 처리됨, SKIP
# 1795/8597 → 이미 처리됨, SKIP
# 1796/8597 → 이미 처리됨, SKIP
# 1797/8597 → 이미 처리됨, SKIP
# 1798/8597 → 이미 처리됨, SKIP
# 1799/8597 → 이미 처리됨, SKIP
# 1800/8597 → 이미 처리됨, SKIP
# 1801/8597 → 이미 처리됨, SKIP
# 1802/8597 → 이미 처리됨, SKIP
# 1803/8597 → 이미 처리됨, SKIP
# 1804/8597 → 이미 처리됨, SKIP
# 1805/8597 → 이미 처리됨, SKIP
# 1806/8597 → 이미 처리됨, SKIP
# 1807/8597 → 이미 처리됨, SKIP
# 1808/8597 → 이미 처리됨, SKIP
# 1809/8597 → 이미 처리됨, SKIP
# 1810/8597 → 이미 처리됨, SKIP
# 1811/8597 → 이미 처리됨, SKIP
# 1812/8597 → 이미 처리됨, SKIP
# 1813/8597 → 이미 처리됨, SKIP
# 1814/8597 → 이미 처리됨, SKIP
# 1815/8597 → 이미 처리됨, SKIP
# 1816/8597 → 이미 처리됨, SKIP
# 1817/8597 → 이미 처리됨, SKIP
# 1818/8597 → 이미 처리됨, SKIP
# 1819/8597 → 이미 처리됨, SKIP
# 1820/8597 → 이미 처리됨, SKIP
# 1821/8597 → 이미 처리됨, SKIP
# 1822/8597 → 이미 처리됨, SKIP
# 1823/8597 → 이미 처리됨, SKIP
# 1824/8597 → 이미 처리됨, SKIP
# 1825/8597 → 이미 처리됨, SKIP
# 1826/8597 → 이미 처리됨, SKIP
# 1827/8597 → 이미 처리됨, SKIP
# 1828/8597 → 이미 처리됨, SKIP
# 1829/8597 → 이미 처리됨, SKIP
# 1830/8597 → 이미 처리됨, SKIP
# 1831/8597 → 이미 처리됨, SKIP
# 1832/8597 → 이미 처리됨, SKIP
# 1833/8597 → 이미 처리됨, SKIP
# 1834/8597 → 이미 처리됨, SKIP
# 1835/8597 → 이미 처리됨, SKIP
# 1836/8597 → 이미 처리됨, SKIP
# 1837/8597 → 이미 처리됨, SKIP
# 1838/8597 → 이미 처리됨, SKIP
# 1839/8597 → 이미 처리됨, SKIP
# 1840/8597 → 이미 처리됨, SKIP
# 1841/8597 → 이미 처리됨, SKIP
# 1842/8597 → 이미 처리됨, SKIP
# 1843/8597 → 이미 처리됨, SKIP
# 1844/8597 → 이미 처리됨, SKIP
# 1845/8597 → 이미 처리됨, SKIP
# 1846/8597 → 이미 처리됨, SKIP
# 1847/8597 → 이미 처리됨, SKIP
# 1848/8597 → 이미 처리됨, SKIP
# 1849/8597 → 이미 처리됨, SKIP
# 1850/8597 → 이미 처리됨, SKIP
# 1851/8597 → 이미 처리됨, SKIP
# 1852/8597 → 이미 처리됨, SKIP
# 1853/8597 → 이미 처리됨, SKIP
# 1854/8597 → 이미 처리됨, SKIP
# 1855/8597 → 이미 처리됨, SKIP
# 1856/8597 → 이미 처리됨, SKIP
# 1857/8597 → 이미 처리됨, SKIP
# 1858/8597 → 이미 처리됨, SKIP
# 1859/8597 → 이미 처리됨, SKIP
# 1860/8597 → 이미 처리됨, SKIP
# 1861/8597 → 이미 처리됨, SKIP
# 1862/8597 → 이미 처리됨, SKIP
# 1863/8597 → 이미 처리됨, SKIP
# 1864/8597 → 이미 처리됨, SKIP
# 1865/8597 → 이미 처리됨, SKIP
# 1866/8597 → 이미 처리됨, SKIP
# 1867/8597 → 이미 처리됨, SKIP
# 1868/8597 → 이미 처리됨, SKIP
# 1869/8597 → 이미 처리됨, SKIP
# 1870/8597 → 이미 처리됨, SKIP
# 1871/8597 → 이미 처리됨, SKIP
# 1872/8597 → 이미 처리됨, SKIP
# 1873/8597 → 이미 처리됨, SKIP
# 1874/8597 → 이미 처리됨, SKIP
# 1875/8597 → 이미 처리됨, SKIP
# 1876/8597 → 이미 처리됨, SKIP
# 1877/8597 → 이미 처리됨, SKIP
# 1878/8597 → 이미 처리됨, SKIP
# 1879/8597 → 이미 처리됨, SKIP
# 1880/8597 → 이미 처리됨, SKIP
# 1881/8597 → 이미 처리됨, SKIP
# 1882/8597 → 이미 처리됨, SKIP
# 1883/8597 → 이미 처리됨, SKIP
# 1884/8597 → 이미 처리됨, SKIP
# 1885/8597 → 이미 처리됨, SKIP
# 1886/8597 → 이미 처리됨, SKIP
# 1887/8597 → 이미 처리됨, SKIP
#
# ▶ 1888/8597 — 주소 검색: 서울특별시 관악구 신림동 28-9
#    ❗ 1차 실패 → 재검색: 서울특별시 관악구 신림동 신동아
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 1889/8597 → 이미 처리됨, SKIP
# 1890/8597 → 이미 처리됨, SKIP
# 1891/8597 → 이미 처리됨, SKIP
# 1892/8597 → 이미 처리됨, SKIP
# 1893/8597 → 이미 처리됨, SKIP
# 1894/8597 → 이미 처리됨, SKIP
# 1895/8597 → 이미 처리됨, SKIP
# 1896/8597 → 이미 처리됨, SKIP
# 1897/8597 → 이미 처리됨, SKIP
# 1898/8597 → 이미 처리됨, SKIP
# 1899/8597 → 이미 처리됨, SKIP
# 1900/8597 → 이미 처리됨, SKIP
# 1901/8597 → 이미 처리됨, SKIP
# 1902/8597 → 이미 처리됨, SKIP
# 1903/8597 → 이미 처리됨, SKIP
# 1904/8597 → 이미 처리됨, SKIP
# 1905/8597 → 이미 처리됨, SKIP
# 1906/8597 → 이미 처리됨, SKIP
# 1907/8597 → 이미 처리됨, SKIP
# 1908/8597 → 이미 처리됨, SKIP
# 1909/8597 → 이미 처리됨, SKIP
# 1910/8597 → 이미 처리됨, SKIP
# 1911/8597 → 이미 처리됨, SKIP
# 1912/8597 → 이미 처리됨, SKIP
# 1913/8597 → 이미 처리됨, SKIP
# 1914/8597 → 이미 처리됨, SKIP
# 1915/8597 → 이미 처리됨, SKIP
# 1916/8597 → 이미 처리됨, SKIP
# ...
# 8027/8597 → 이미 처리됨, SKIP
# 8028/8597 → 이미 처리됨, SKIP
# 8029/8597 → 이미 처리됨, SKIP
# 8030/8597 → 이미 처리됨, SKIP
# 8031/8597 → 이미 처리됨, SKIP
# 8032/8597 → 이미 처리됨, SKIP
# 8033/8597 → 이미 처리됨, SKIP
# 8034/8597 → 이미 처리됨, SKIP
# 8035/8597 → 이미 처리됨, SKIP
# 8036/8597 → 이미 처리됨, SKIP
# 8037/8597 → 이미 처리됨, SKIP
# 8038/8597 → 이미 처리됨, SKIP
# 8039/8597 → 이미 처리됨, SKIP
# 8040/8597 → 이미 처리됨, SKIP
# 8041/8597 → 이미 처리됨, SKIP
# 8042/8597 → 이미 처리됨, SKIP
# 8043/8597 → 이미 처리됨, SKIP
# 8044/8597 → 이미 처리됨, SKIP
# 8045/8597 → 이미 처리됨, SKIP
# 8046/8597 → 이미 처리됨, SKIP
# 8047/8597 → 이미 처리됨, SKIP
# 8048/8597 → 이미 처리됨, SKIP
# 8049/8597 → 이미 처리됨, SKIP
# 8050/8597 → 이미 처리됨, SKIP
# 8051/8597 → 이미 처리됨, SKIP
# 8052/8597 → 이미 처리됨, SKIP
# 8053/8597 → 이미 처리됨, SKIP
# 8054/8597 → 이미 처리됨, SKIP
# 8055/8597 → 이미 처리됨, SKIP
# 8056/8597 → 이미 처리됨, SKIP
# 8057/8597 → 이미 처리됨, SKIP
# 8058/8597 → 이미 처리됨, SKIP
# 8059/8597 → 이미 처리됨, SKIP
# 8060/8597 → 이미 처리됨, SKIP
# 8061/8597 → 이미 처리됨, SKIP
# 8062/8597 → 이미 처리됨, SKIP
# 8063/8597 → 이미 처리됨, SKIP
# 8064/8597 → 이미 처리됨, SKIP
# 8065/8597 → 이미 처리됨, SKIP
# 8066/8597 → 이미 처리됨, SKIP
# 8067/8597 → 이미 처리됨, SKIP
# 8068/8597 → 이미 처리됨, SKIP
# 8069/8597 → 이미 처리됨, SKIP
# 8070/8597 → 이미 처리됨, SKIP
# 8071/8597 → 이미 처리됨, SKIP
# 8072/8597 → 이미 처리됨, SKIP
# 8073/8597 → 이미 처리됨, SKIP
# 8074/8597 → 이미 처리됨, SKIP
# 8075/8597 → 이미 처리됨, SKIP
# 8076/8597 → 이미 처리됨, SKIP
# 8077/8597 → 이미 처리됨, SKIP
# 8078/8597 → 이미 처리됨, SKIP
# 8079/8597 → 이미 처리됨, SKIP
# 8080/8597 → 이미 처리됨, SKIP
# 8081/8597 → 이미 처리됨, SKIP
# 8082/8597 → 이미 처리됨, SKIP
# 8083/8597 → 이미 처리됨, SKIP
# 8084/8597 → 이미 처리됨, SKIP
# 8085/8597 → 이미 처리됨, SKIP
# 8086/8597 → 이미 처리됨, SKIP
# 8087/8597 → 이미 처리됨, SKIP
# 8088/8597 → 이미 처리됨, SKIP
# 8089/8597 → 이미 처리됨, SKIP
# 8090/8597 → 이미 처리됨, SKIP
# 8091/8597 → 이미 처리됨, SKIP
# 8092/8597 → 이미 처리됨, SKIP
# 8093/8597 → 이미 처리됨, SKIP
# 8094/8597 → 이미 처리됨, SKIP
# 8095/8597 → 이미 처리됨, SKIP
# 8096/8597 → 이미 처리됨, SKIP
# 8097/8597 → 이미 처리됨, SKIP
# 8098/8597 → 이미 처리됨, SKIP
# 8099/8597 → 이미 처리됨, SKIP
# 8100/8597 → 이미 처리됨, SKIP
# 8101/8597 → 이미 처리됨, SKIP
# 8102/8597 → 이미 처리됨, SKIP
# 8103/8597 → 이미 처리됨, SKIP
# 8104/8597 → 이미 처리됨, SKIP
# 8105/8597 → 이미 처리됨, SKIP
# 8106/8597 → 이미 처리됨, SKIP
# 8107/8597 → 이미 처리됨, SKIP
# 8108/8597 → 이미 처리됨, SKIP
# 8109/8597 → 이미 처리됨, SKIP
# 8110/8597 → 이미 처리됨, SKIP
# 8111/8597 → 이미 처리됨, SKIP
# 8112/8597 → 이미 처리됨, SKIP
# 8113/8597 → 이미 처리됨, SKIP
# 8114/8597 → 이미 처리됨, SKIP
# 8115/8597 → 이미 처리됨, SKIP
# 8116/8597 → 이미 처리됨, SKIP
# 8117/8597 → 이미 처리됨, SKIP
# 8118/8597 → 이미 처리됨, SKIP
# 8119/8597 → 이미 처리됨, SKIP
# 8120/8597 → 이미 처리됨, SKIP
# 8121/8597 → 이미 처리됨, SKIP
# 8122/8597 → 이미 처리됨, SKIP
# 8123/8597 → 이미 처리됨, SKIP
# 8124/8597 → 이미 처리됨, SKIP
# 8125/8597 → 이미 처리됨, SKIP
# 8126/8597 → 이미 처리됨, SKIP
# 8127/8597 → 이미 처리됨, SKIP
# 8128/8597 → 이미 처리됨, SKIP
# 8129/8597 → 이미 처리됨, SKIP
# 8130/8597 → 이미 처리됨, SKIP
# 8131/8597 → 이미 처리됨, SKIP
# 8132/8597 → 이미 처리됨, SKIP
# 8133/8597 → 이미 처리됨, SKIP
# 8134/8597 → 이미 처리됨, SKIP
# 8135/8597 → 이미 처리됨, SKIP
# 8136/8597 → 이미 처리됨, SKIP
# 8137/8597 → 이미 처리됨, SKIP
# 8138/8597 → 이미 처리됨, SKIP
# 8139/8597 → 이미 처리됨, SKIP
# 8140/8597 → 이미 처리됨, SKIP
# 8141/8597 → 이미 처리됨, SKIP
# 8142/8597 → 이미 처리됨, SKIP
# 8143/8597 → 이미 처리됨, SKIP
# 8144/8597 → 이미 처리됨, SKIP
# 8145/8597 → 이미 처리됨, SKIP
# 8146/8597 → 이미 처리됨, SKIP
# 8147/8597 → 이미 처리됨, SKIP
# 8148/8597 → 이미 처리됨, SKIP
# 8149/8597 → 이미 처리됨, SKIP
# 8150/8597 → 이미 처리됨, SKIP
# 8151/8597 → 이미 처리됨, SKIP
# 8152/8597 → 이미 처리됨, SKIP
# 8153/8597 → 이미 처리됨, SKIP
# 8154/8597 → 이미 처리됨, SKIP
# 8155/8597 → 이미 처리됨, SKIP
# 8156/8597 → 이미 처리됨, SKIP
# 8157/8597 → 이미 처리됨, SKIP
# 8158/8597 → 이미 처리됨, SKIP
# 8159/8597 → 이미 처리됨, SKIP
# 8160/8597 → 이미 처리됨, SKIP
# 8161/8597 → 이미 처리됨, SKIP
# 8162/8597 → 이미 처리됨, SKIP
# 8163/8597 → 이미 처리됨, SKIP
# 8164/8597 → 이미 처리됨, SKIP
# 8165/8597 → 이미 처리됨, SKIP
# 8166/8597 → 이미 처리됨, SKIP
# 8167/8597 → 이미 처리됨, SKIP
# 8168/8597 → 이미 처리됨, SKIP
# 8169/8597 → 이미 처리됨, SKIP
# 8170/8597 → 이미 처리됨, SKIP
# 8171/8597 → 이미 처리됨, SKIP
# 8172/8597 → 이미 처리됨, SKIP
# 8173/8597 → 이미 처리됨, SKIP
# 8174/8597 → 이미 처리됨, SKIP
# 8175/8597 → 이미 처리됨, SKIP
# 8176/8597 → 이미 처리됨, SKIP
# 8177/8597 → 이미 처리됨, SKIP
# 8178/8597 → 이미 처리됨, SKIP
# 8179/8597 → 이미 처리됨, SKIP
# 8180/8597 → 이미 처리됨, SKIP
# 8181/8597 → 이미 처리됨, SKIP
# 8182/8597 → 이미 처리됨, SKIP
# 8183/8597 → 이미 처리됨, SKIP
# 8184/8597 → 이미 처리됨, SKIP
# 8185/8597 → 이미 처리됨, SKIP
# 8186/8597 → 이미 처리됨, SKIP
# 8187/8597 → 이미 처리됨, SKIP
# 8188/8597 → 이미 처리됨, SKIP
# 8189/8597 → 이미 처리됨, SKIP
# 8190/8597 → 이미 처리됨, SKIP
# 8191/8597 → 이미 처리됨, SKIP
# 8192/8597 → 이미 처리됨, SKIP
# 8193/8597 → 이미 처리됨, SKIP
# 8194/8597 → 이미 처리됨, SKIP
# 8195/8597 → 이미 처리됨, SKIP
# 8196/8597 → 이미 처리됨, SKIP
# 8197/8597 → 이미 처리됨, SKIP
# 8198/8597 → 이미 처리됨, SKIP
# 8199/8597 → 이미 처리됨, SKIP
# 8200/8597 → 이미 처리됨, SKIP
# 8201/8597 → 이미 처리됨, SKIP
# 8202/8597 → 이미 처리됨, SKIP
# 8203/8597 → 이미 처리됨, SKIP
# 8204/8597 → 이미 처리됨, SKIP
# 8205/8597 → 이미 처리됨, SKIP
# 8206/8597 → 이미 처리됨, SKIP
# 8207/8597 → 이미 처리됨, SKIP
# 8208/8597 → 이미 처리됨, SKIP
# 8209/8597 → 이미 처리됨, SKIP
# 8210/8597 → 이미 처리됨, SKIP
# 8211/8597 → 이미 처리됨, SKIP
# 8212/8597 → 이미 처리됨, SKIP
# 8213/8597 → 이미 처리됨, SKIP
# 8214/8597 → 이미 처리됨, SKIP
# 8215/8597 → 이미 처리됨, SKIP
# 8216/8597 → 이미 처리됨, SKIP
# 8217/8597 → 이미 처리됨, SKIP
# 8218/8597 → 이미 처리됨, SKIP
# 8219/8597 → 이미 처리됨, SKIP
# 8220/8597 → 이미 처리됨, SKIP
# 8221/8597 → 이미 처리됨, SKIP
# 8222/8597 → 이미 처리됨, SKIP
# 8223/8597 → 이미 처리됨, SKIP
# 8224/8597 → 이미 처리됨, SKIP
# 8225/8597 → 이미 처리됨, SKIP
# 8226/8597 → 이미 처리됨, SKIP
# 8227/8597 → 이미 처리됨, SKIP
# 8228/8597 → 이미 처리됨, SKIP
# 8229/8597 → 이미 처리됨, SKIP
# 8230/8597 → 이미 처리됨, SKIP
# 8231/8597 → 이미 처리됨, SKIP
# 8232/8597 → 이미 처리됨, SKIP
# 8233/8597 → 이미 처리됨, SKIP
# 8234/8597 → 이미 처리됨, SKIP
# 8235/8597 → 이미 처리됨, SKIP
# 8236/8597 → 이미 처리됨, SKIP
#
# ▶ 8237/8597 — 주소 검색: 서울특별시 관악구 사당동 1152
#    ❗ 1차 실패 → 재검색: 서울특별시 관악구 사당동 관악푸르지오102동
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8238/8597 → 이미 처리됨, SKIP
# 8239/8597 → 이미 처리됨, SKIP
# 8240/8597 → 이미 처리됨, SKIP
# 8241/8597 → 이미 처리됨, SKIP
# 8242/8597 → 이미 처리됨, SKIP
# 8243/8597 → 이미 처리됨, SKIP
# 8244/8597 → 이미 처리됨, SKIP
# 8245/8597 → 이미 처리됨, SKIP
# 8246/8597 → 이미 처리됨, SKIP
# 8247/8597 → 이미 처리됨, SKIP
# 8248/8597 → 이미 처리됨, SKIP
# 8249/8597 → 이미 처리됨, SKIP
# 8250/8597 → 이미 처리됨, SKIP
# 8251/8597 → 이미 처리됨, SKIP
# 8252/8597 → 이미 처리됨, SKIP
# 8253/8597 → 이미 처리됨, SKIP
# 8254/8597 → 이미 처리됨, SKIP
#
# ▶ 8255/8597 — 주소 검색: 서울특별시 중랑구 면목동 164-10
#    ❗ 1차 실패 → 재검색: 서울특별시 중랑구 면목동 사가정센트럴아이파크
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8256/8597 → 이미 처리됨, SKIP
# 8257/8597 → 이미 처리됨, SKIP
# 8258/8597 → 이미 처리됨, SKIP
# 8259/8597 → 이미 처리됨, SKIP
# 8260/8597 → 이미 처리됨, SKIP
# 8261/8597 → 이미 처리됨, SKIP
# 8262/8597 → 이미 처리됨, SKIP
# 8263/8597 → 이미 처리됨, SKIP
# 8264/8597 → 이미 처리됨, SKIP
# 8265/8597 → 이미 처리됨, SKIP
# 8266/8597 → 이미 처리됨, SKIP
# 8267/8597 → 이미 처리됨, SKIP
# 8268/8597 → 이미 처리됨, SKIP
# 8269/8597 → 이미 처리됨, SKIP
# 8270/8597 → 이미 처리됨, SKIP
# 8271/8597 → 이미 처리됨, SKIP
# 8272/8597 → 이미 처리됨, SKIP
# 8273/8597 → 이미 처리됨, SKIP
# 8274/8597 → 이미 처리됨, SKIP
# 8275/8597 → 이미 처리됨, SKIP
# 8276/8597 → 이미 처리됨, SKIP
# 8277/8597 → 이미 처리됨, SKIP
# 8278/8597 → 이미 처리됨, SKIP
# 8279/8597 → 이미 처리됨, SKIP
# 8280/8597 → 이미 처리됨, SKIP
# 8281/8597 → 이미 처리됨, SKIP
# 8282/8597 → 이미 처리됨, SKIP
# 8283/8597 → 이미 처리됨, SKIP
# 8284/8597 → 이미 처리됨, SKIP
# 8285/8597 → 이미 처리됨, SKIP
# 8286/8597 → 이미 처리됨, SKIP
# 8287/8597 → 이미 처리됨, SKIP
# 8288/8597 → 이미 처리됨, SKIP
# 8289/8597 → 이미 처리됨, SKIP
# 8290/8597 → 이미 처리됨, SKIP
# 8291/8597 → 이미 처리됨, SKIP
# 8292/8597 → 이미 처리됨, SKIP
# 8293/8597 → 이미 처리됨, SKIP
# 8294/8597 → 이미 처리됨, SKIP
# 8295/8597 → 이미 처리됨, SKIP
# 8296/8597 → 이미 처리됨, SKIP
# 8297/8597 → 이미 처리됨, SKIP
# 8298/8597 → 이미 처리됨, SKIP
# 8299/8597 → 이미 처리됨, SKIP
# 8300/8597 → 이미 처리됨, SKIP
# 8301/8597 → 이미 처리됨, SKIP
# 8302/8597 → 이미 처리됨, SKIP
#
# ▶ 8303/8597 — 주소 검색: 서울특별시 서대문구 남가좌동 286-1
#    ❗ 1차 실패 → 재검색: 서울특별시 서대문구 남가좌동 DMC금호리첸시아
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8304/8597 → 이미 처리됨, SKIP
# 8305/8597 → 이미 처리됨, SKIP
# 8306/8597 → 이미 처리됨, SKIP
# 8307/8597 → 이미 처리됨, SKIP
# 8308/8597 → 이미 처리됨, SKIP
# 8309/8597 → 이미 처리됨, SKIP
# 8310/8597 → 이미 처리됨, SKIP
# 8311/8597 → 이미 처리됨, SKIP
# 8312/8597 → 이미 처리됨, SKIP
# 8313/8597 → 이미 처리됨, SKIP
# 8314/8597 → 이미 처리됨, SKIP
# 8315/8597 → 이미 처리됨, SKIP
# 8316/8597 → 이미 처리됨, SKIP
# 8317/8597 → 이미 처리됨, SKIP
#
# ▶ 8318/8597 — 주소 검색: 서울특별시 서대문구 홍제동 270-1
#    ❗ 1차 실패 → 재검색: 서울특별시 서대문구 홍제동 홍제역해링턴플레이스
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8319/8597 → 이미 처리됨, SKIP
# 8320/8597 → 이미 처리됨, SKIP
# 8321/8597 → 이미 처리됨, SKIP
# 8322/8597 → 이미 처리됨, SKIP
# 8323/8597 → 이미 처리됨, SKIP
# 8324/8597 → 이미 처리됨, SKIP
# 8325/8597 → 이미 처리됨, SKIP
# 8326/8597 → 이미 처리됨, SKIP
# 8327/8597 → 이미 처리됨, SKIP
# 8328/8597 → 이미 처리됨, SKIP
# 8329/8597 → 이미 처리됨, SKIP
# 8330/8597 → 이미 처리됨, SKIP
# 8331/8597 → 이미 처리됨, SKIP
# 8332/8597 → 이미 처리됨, SKIP
# 8333/8597 → 이미 처리됨, SKIP
# 8334/8597 → 이미 처리됨, SKIP
# 8335/8597 → 이미 처리됨, SKIP
# 8336/8597 → 이미 처리됨, SKIP
# 8337/8597 → 이미 처리됨, SKIP
# 8338/8597 → 이미 처리됨, SKIP
# 8339/8597 → 이미 처리됨, SKIP
# 8340/8597 → 이미 처리됨, SKIP
# 8341/8597 → 이미 처리됨, SKIP
# 8342/8597 → 이미 처리됨, SKIP
# 8343/8597 → 이미 처리됨, SKIP
# 8344/8597 → 이미 처리됨, SKIP
# 8345/8597 → 이미 처리됨, SKIP
# 8346/8597 → 이미 처리됨, SKIP
# 8347/8597 → 이미 처리됨, SKIP
# 8348/8597 → 이미 처리됨, SKIP
# 8349/8597 → 이미 처리됨, SKIP
# 8350/8597 → 이미 처리됨, SKIP
# 8351/8597 → 이미 처리됨, SKIP
# 8352/8597 → 이미 처리됨, SKIP
# 8353/8597 → 이미 처리됨, SKIP
# 8354/8597 → 이미 처리됨, SKIP
# 8355/8597 → 이미 처리됨, SKIP
# 8356/8597 → 이미 처리됨, SKIP
#
# ▶ 8357/8597 — 주소 검색: 서울특별시 강서구 방화동 905
#    ❗ 1차 실패 → 재검색: 서울특별시 강서구 방화동 마곡노블리안
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8358/8597 → 이미 처리됨, SKIP
# 8359/8597 → 이미 처리됨, SKIP
# 8360/8597 → 이미 처리됨, SKIP
# 8361/8597 → 이미 처리됨, SKIP
# 8362/8597 → 이미 처리됨, SKIP
# 8363/8597 → 이미 처리됨, SKIP
# 8364/8597 → 이미 처리됨, SKIP
# 8365/8597 → 이미 처리됨, SKIP
# 8366/8597 → 이미 처리됨, SKIP
# 8367/8597 → 이미 처리됨, SKIP
# 8368/8597 → 이미 처리됨, SKIP
# 8369/8597 → 이미 처리됨, SKIP
# 8370/8597 → 이미 처리됨, SKIP
# 8371/8597 → 이미 처리됨, SKIP
# 8372/8597 → 이미 처리됨, SKIP
# 8373/8597 → 이미 처리됨, SKIP
# 8374/8597 → 이미 처리됨, SKIP
# 8375/8597 → 이미 처리됨, SKIP
# 8376/8597 → 이미 처리됨, SKIP
# 8377/8597 → 이미 처리됨, SKIP
# 8378/8597 → 이미 처리됨, SKIP
# 8379/8597 → 이미 처리됨, SKIP
# 8380/8597 → 이미 처리됨, SKIP
# 8381/8597 → 이미 처리됨, SKIP
# 8382/8597 → 이미 처리됨, SKIP
# 8383/8597 → 이미 처리됨, SKIP
# 8384/8597 → 이미 처리됨, SKIP
# 8385/8597 → 이미 처리됨, SKIP
# 8386/8597 → 이미 처리됨, SKIP
# 8387/8597 → 이미 처리됨, SKIP
# 8388/8597 → 이미 처리됨, SKIP
# 8389/8597 → 이미 처리됨, SKIP
# 8390/8597 → 이미 처리됨, SKIP
# 8391/8597 → 이미 처리됨, SKIP
# 8392/8597 → 이미 처리됨, SKIP
# 8393/8597 → 이미 처리됨, SKIP
# 8394/8597 → 이미 처리됨, SKIP
# 8395/8597 → 이미 처리됨, SKIP
# 8396/8597 → 이미 처리됨, SKIP
# 8397/8597 → 이미 처리됨, SKIP
# 8398/8597 → 이미 처리됨, SKIP
# 8399/8597 → 이미 처리됨, SKIP
# 8400/8597 → 이미 처리됨, SKIP
# 8401/8597 → 이미 처리됨, SKIP
# 8402/8597 → 이미 처리됨, SKIP
# 8403/8597 → 이미 처리됨, SKIP
# 8404/8597 → 이미 처리됨, SKIP
# 8405/8597 → 이미 처리됨, SKIP
# 8406/8597 → 이미 처리됨, SKIP
# 8407/8597 → 이미 처리됨, SKIP
# 8408/8597 → 이미 처리됨, SKIP
# 8409/8597 → 이미 처리됨, SKIP
# 8410/8597 → 이미 처리됨, SKIP
# 8411/8597 → 이미 처리됨, SKIP
# 8412/8597 → 이미 처리됨, SKIP
# 8413/8597 → 이미 처리됨, SKIP
# 8414/8597 → 이미 처리됨, SKIP
# 8415/8597 → 이미 처리됨, SKIP
# 8416/8597 → 이미 처리됨, SKIP
# 8417/8597 → 이미 처리됨, SKIP
# 8418/8597 → 이미 처리됨, SKIP
# 8419/8597 → 이미 처리됨, SKIP
# 8420/8597 → 이미 처리됨, SKIP
# 8421/8597 → 이미 처리됨, SKIP
# 8422/8597 → 이미 처리됨, SKIP
# 8423/8597 → 이미 처리됨, SKIP
# 8424/8597 → 이미 처리됨, SKIP
# 8425/8597 → 이미 처리됨, SKIP
# 8426/8597 → 이미 처리됨, SKIP
# 8427/8597 → 이미 처리됨, SKIP
# 8428/8597 → 이미 처리됨, SKIP
# 8429/8597 → 이미 처리됨, SKIP
# 8430/8597 → 이미 처리됨, SKIP
# 8431/8597 → 이미 처리됨, SKIP
# 8432/8597 → 이미 처리됨, SKIP
# 8433/8597 → 이미 처리됨, SKIP
# 8434/8597 → 이미 처리됨, SKIP
# 8435/8597 → 이미 처리됨, SKIP
# 8436/8597 → 이미 처리됨, SKIP
# 8437/8597 → 이미 처리됨, SKIP
# 8438/8597 → 이미 처리됨, SKIP
# 8439/8597 → 이미 처리됨, SKIP
# 8440/8597 → 이미 처리됨, SKIP
# 8441/8597 → 이미 처리됨, SKIP
# 8442/8597 → 이미 처리됨, SKIP
# 8443/8597 → 이미 처리됨, SKIP
# 8444/8597 → 이미 처리됨, SKIP
# 8445/8597 → 이미 처리됨, SKIP
# 8446/8597 → 이미 처리됨, SKIP
#
# ▶ 8447/8597 — 주소 검색: 서울특별시 구로구 고척동 97
#    ❗ 1차 실패 → 재검색: 서울특별시 구로구 고척동 더헤리츠
#    ❌ 최종 실패 → lat/lng 기록 안 함
#
# ▶ 8448/8597 — 주소 검색: 서울특별시 강서구 화곡동 1027-50
#    ❗ 1차 실패 → 재검색: 서울특별시 강서구 화곡동 우장산숲아이파크
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8449/8597 → 이미 처리됨, SKIP
# 8450/8597 → 이미 처리됨, SKIP
# 8451/8597 → 이미 처리됨, SKIP
# 8452/8597 → 이미 처리됨, SKIP
# 8453/8597 → 이미 처리됨, SKIP
# 8454/8597 → 이미 처리됨, SKIP
# 8455/8597 → 이미 처리됨, SKIP
# 8456/8597 → 이미 처리됨, SKIP
# 8457/8597 → 이미 처리됨, SKIP
# 8458/8597 → 이미 처리됨, SKIP
# 8459/8597 → 이미 처리됨, SKIP
# 8460/8597 → 이미 처리됨, SKIP
#
# ▶ 8461/8597 — 주소 검색: 서울특별시 서대문구 홍은동 338-5
#    ❗ 1차 실패 → 재검색: 서울특별시 서대문구 홍은동 힐스테이트홍은포레스트
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8462/8597 → 이미 처리됨, SKIP
# 8463/8597 → 이미 처리됨, SKIP
# 8464/8597 → 이미 처리됨, SKIP
# 8465/8597 → 이미 처리됨, SKIP
# 8466/8597 → 이미 처리됨, SKIP
# 8467/8597 → 이미 처리됨, SKIP
# 8468/8597 → 이미 처리됨, SKIP
# 8469/8597 → 이미 처리됨, SKIP
# 8470/8597 → 이미 처리됨, SKIP
#
# ▶ 8471/8597 — 주소 검색: 서울특별시 강남구 대치동 977
#    ❗ 1차 실패 → 재검색: 서울특별시 강남구 대치동 (977-)
#    ✅ 성공 → 주소 업데이트: 서울 강남구 대치동 / 좌표: (37.4932421505465, 127.056693501258)
# 8472/8597 → 이미 처리됨, SKIP
# 8473/8597 → 이미 처리됨, SKIP
# 8474/8597 → 이미 처리됨, SKIP
# 8475/8597 → 이미 처리됨, SKIP
# 8476/8597 → 이미 처리됨, SKIP
# 8477/8597 → 이미 처리됨, SKIP
# 8478/8597 → 이미 처리됨, SKIP
# 8479/8597 → 이미 처리됨, SKIP
# 8480/8597 → 이미 처리됨, SKIP
#
# ▶ 8481/8597 — 주소 검색: 서울특별시 중랑구 면목동 55-14
#    ❗ 1차 실패 → 재검색: 서울특별시 중랑구 면목동 용마산모아엘가파크포레
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8482/8597 → 이미 처리됨, SKIP
#
# ▶ 8483/8597 — 주소 검색: 서울특별시 동작구 봉천동 1000
#    ❗ 1차 실패 → 재검색: 서울특별시 동작구 봉천동 현대(관악)
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8484/8597 → 이미 처리됨, SKIP
# 8485/8597 → 이미 처리됨, SKIP
# 8486/8597 → 이미 처리됨, SKIP
# 8487/8597 → 이미 처리됨, SKIP
# 8488/8597 → 이미 처리됨, SKIP
# 8489/8597 → 이미 처리됨, SKIP
# 8490/8597 → 이미 처리됨, SKIP
# 8491/8597 → 이미 처리됨, SKIP
# 8492/8597 → 이미 처리됨, SKIP
# 8493/8597 → 이미 처리됨, SKIP
# 8494/8597 → 이미 처리됨, SKIP
# 8495/8597 → 이미 처리됨, SKIP
# 8496/8597 → 이미 처리됨, SKIP
# 8497/8597 → 이미 처리됨, SKIP
# 8498/8597 → 이미 처리됨, SKIP
# 8499/8597 → 이미 처리됨, SKIP
# 8500/8597 → 이미 처리됨, SKIP
# 8501/8597 → 이미 처리됨, SKIP
# 8502/8597 → 이미 처리됨, SKIP
# 8503/8597 → 이미 처리됨, SKIP
# 8504/8597 → 이미 처리됨, SKIP
# 8505/8597 → 이미 처리됨, SKIP
# 8506/8597 → 이미 처리됨, SKIP
# 8507/8597 → 이미 처리됨, SKIP
# 8508/8597 → 이미 처리됨, SKIP
# 8509/8597 → 이미 처리됨, SKIP
# 8510/8597 → 이미 처리됨, SKIP
# 8511/8597 → 이미 처리됨, SKIP
# 8512/8597 → 이미 처리됨, SKIP
# 8513/8597 → 이미 처리됨, SKIP
# 8514/8597 → 이미 처리됨, SKIP
# 8515/8597 → 이미 처리됨, SKIP
# 8516/8597 → 이미 처리됨, SKIP
# 8517/8597 → 이미 처리됨, SKIP
# 8518/8597 → 이미 처리됨, SKIP
# 8519/8597 → 이미 처리됨, SKIP
# 8520/8597 → 이미 처리됨, SKIP
# 8521/8597 → 이미 처리됨, SKIP
# 8522/8597 → 이미 처리됨, SKIP
# 8523/8597 → 이미 처리됨, SKIP
#
# ▶ 8524/8597 — 주소 검색: 서울특별시 동대문구 용두동 39-1
#    ❗ 1차 실패 → 재검색: 서울특별시 동대문구 용두동 청량리역한양수자인그라시엘
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8525/8597 → 이미 처리됨, SKIP
# 8526/8597 → 이미 처리됨, SKIP
# 8527/8597 → 이미 처리됨, SKIP
# 8528/8597 → 이미 처리됨, SKIP
# 8529/8597 → 이미 처리됨, SKIP
# 8530/8597 → 이미 처리됨, SKIP
# 8531/8597 → 이미 처리됨, SKIP
# 8532/8597 → 이미 처리됨, SKIP
# 8533/8597 → 이미 처리됨, SKIP
# 8534/8597 → 이미 처리됨, SKIP
# 8535/8597 → 이미 처리됨, SKIP
# 8536/8597 → 이미 처리됨, SKIP
# 8537/8597 → 이미 처리됨, SKIP
# 8538/8597 → 이미 처리됨, SKIP
# 8539/8597 → 이미 처리됨, SKIP
# 8540/8597 → 이미 처리됨, SKIP
# 8541/8597 → 이미 처리됨, SKIP
# 8542/8597 → 이미 처리됨, SKIP
# 8543/8597 → 이미 처리됨, SKIP
# 8544/8597 → 이미 처리됨, SKIP
# 8545/8597 → 이미 처리됨, SKIP
# 8546/8597 → 이미 처리됨, SKIP
#
# ▶ 8547/8597 — 주소 검색: 서울특별시 강서구 방화동 1467
#    ❗ 1차 실패 → 재검색: 서울특별시 강서구 방화동 마곡우림필유아파트
#    ❌ 최종 실패 → lat/lng 기록 안 함
#
# ▶ 8548/8597 — 주소 검색: 서울특별시 강서구 방화동 1252
#    ❗ 1차 실패 → 재검색: 서울특별시 강서구 방화동 마곡보타닉경남아너스빌
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8549/8597 → 이미 처리됨, SKIP
# 8550/8597 → 이미 처리됨, SKIP
# 8551/8597 → 이미 처리됨, SKIP
# 8552/8597 → 이미 처리됨, SKIP
# 8553/8597 → 이미 처리됨, SKIP
#
# ▶ 8554/8597 — 주소 검색: 서울특별시 강서구 방화동 1454
#    ❗ 1차 실패 → 재검색: 서울특별시 강서구 방화동 마곡태승훼미리아파트
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8555/8597 → 이미 처리됨, SKIP
# 8556/8597 → 이미 처리됨, SKIP
# 8557/8597 → 이미 처리됨, SKIP
# 8558/8597 → 이미 처리됨, SKIP
#
# ▶ 8559/8597 — 주소 검색: 서울특별시 강서구 방화동 1181
#    ❗ 1차 실패 → 재검색: 서울특별시 강서구 방화동 마곡청구아파트
#    ❌ 최종 실패 → lat/lng 기록 안 함
#
# ▶ 8560/8597 — 주소 검색: 서울특별시 강서구 방화동 1171
#    ❗ 1차 실패 → 재검색: 서울특별시 강서구 방화동 마곡현대아파트
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8561/8597 → 이미 처리됨, SKIP
# 8562/8597 → 이미 처리됨, SKIP
# 8563/8597 → 이미 처리됨, SKIP
# 8564/8597 → 이미 처리됨, SKIP
# 8565/8597 → 이미 처리됨, SKIP
# 8566/8597 → 이미 처리됨, SKIP
# 8567/8597 → 이미 처리됨, SKIP
# 8568/8597 → 이미 처리됨, SKIP
#
# ▶ 8569/8597 — 주소 검색: 서울특별시 강서구 방화동 1525
#    ❗ 1차 실패 → 재검색: 서울특별시 강서구 방화동 마곡푸르지오
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8570/8597 → 이미 처리됨, SKIP
# 8571/8597 → 이미 처리됨, SKIP
# 8572/8597 → 이미 처리됨, SKIP
# 8573/8597 → 이미 처리됨, SKIP
# 8574/8597 → 이미 처리됨, SKIP
# 8575/8597 → 이미 처리됨, SKIP
# 8576/8597 → 이미 처리됨, SKIP
# 8577/8597 → 이미 처리됨, SKIP
# 8578/8597 → 이미 처리됨, SKIP
# 8579/8597 → 이미 처리됨, SKIP
# 8580/8597 → 이미 처리됨, SKIP
# 8581/8597 → 이미 처리됨, SKIP
# 8582/8597 → 이미 처리됨, SKIP
# 8583/8597 → 이미 처리됨, SKIP
# 8584/8597 → 이미 처리됨, SKIP
# 8585/8597 → 이미 처리됨, SKIP
# 8586/8597 → 이미 처리됨, SKIP
# 8587/8597 → 이미 처리됨, SKIP
#
# ▶ 8588/8597 — 주소 검색: 서울특별시 중랑구 신내동 488
#    ❗ 1차 실패 → 재검색: 서울특별시 중랑구 신내동 망우역신원아침도시
#    ❌ 최종 실패 → lat/lng 기록 안 함
# 8589/8597 → 이미 처리됨, SKIP
# 8590/8597 → 이미 처리됨, SKIP
# 8591/8597 → 이미 처리됨, SKIP
# 8592/8597 → 이미 처리됨, SKIP
# 8593/8597 → 이미 처리됨, SKIP
# 8594/8597 → 이미 처리됨, SKIP
# 8595/8597 → 이미 처리됨, SKIP
# 8596/8597 → 이미 처리됨, SKIP
# 8597/8597 → 이미 처리됨, SKIP
#
# 🎉 처리 완료 → output_with_latlng.xlsx 저장됨!
